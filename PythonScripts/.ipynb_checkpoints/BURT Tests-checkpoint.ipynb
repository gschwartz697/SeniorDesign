# %%
import csv

# initializing the titles and rows list 
fields = [] 
rows = [] 
# raw_questions = []
raw_questions_to_hw = dict()

filename = 'contributions.csv'
# reading csv file 
with open(filename, 'r', encoding="utf8") as csvfile: 
    # creating a csv reader object 
    csvreader = csv.reader(csvfile) 
      
    # extracting field names through first row 
    fields = next(csvreader) 
  
    # extracting each data row one by one 
    for row in csvreader: 
        rows.append(row) 

    curr_question = ""
    curr_text = ""
    curr_topic = ""
    curr_folder = ""
    curr_answer = ""
    curr_number = 0
    curr_follow_up = 0
    endorsed = 0
    
    # This will help us take the most recent version because it always comes first
    already_filled = 0
    for row in rows[:]: 
        # parsing each column of a row 
        for col,field in zip(row, fields): 
            if(field == "Post Number" and curr_number != int(col)):
                curr_folders = curr_folder.split()
                for folder in curr_folders:
                    if folder[-1] == ';':
                            folder = folder[:-1]
                    if(curr_question != "" and curr_answer != ""):
                        if folder in raw_questions_to_hw:
                            raw_questions = raw_questions_to_hw[folder]
                            raw_questions.append(curr_question)
                            raw_questions_to_hw.update({folder : raw_questions})
                        else:
                            raw_questions = []
                            raw_questions.append(curr_question)
                            raw_questions_to_hw.update({curr_folder : raw_questions})
                curr_number = int(col)
                curr_follow_up = 0
                curr_question = ""
                already_filled = 0
                curr_answer = ""
                curr_topic = ""
                curr_folder = ""
                endorsed = 0
                
            elif(field == "Submission HTML Removed"): #the question could also be in subject
                curr_text = col
                
            elif(field == "Subject"): #We want to check if this is actually the question eventaully
                curr_topic = col
                
            elif(field == "Folders"):
                curr_folder = col
                
            elif(field == "Endorsed by Instructor"):
                if(col == "TRUE"):
                    endorsed = 1
                else:
                    endorsed = 0
            elif(field == "Part of Post"):
                if(col == "started_off_question"):
                    if(already_filled == 0):
                        curr_question = curr_text
                    already_filled = 0
                elif(col == "updated_question"):
                    # update question entry to post and follow up numbers
                    if(already_filled == 0):
                        curr_question = curr_text
                        already_filled = 1
                        
                elif(col == "updated_i_answer"):
                    # update last entry to the post and follow up number
                    # what if it was appended? how do we update just the end?
                    if(already_filled == 0):
                        curr_answer = curr_answer + "\n" + curr_text
                        already_filled = 1
                    endorsed = 1
                elif(col == "started_off_i_answer"):
                    if(already_filled == 0):
                        curr_answer = curr_answer + "\n" + curr_text
                    already_filled = 0
                    endorsed = 1
                    
                elif(col == "updated_s_answer"):
                    # update last entry to the post and follow up number
                    # what if it was appended? how do we update just the end?
                    if(already_filled == 0):
                        curr_answer = curr_answer + "\n" + curr_text
                        already_filled = 1
                elif(col == "started_off_s_answer"):
                    # append to answer - if it was previously endorsed and were appending should we keep it endorsed?
                    if(already_filled == 0):
                        curr_answer = curr_answer + "\n" + curr_text
                    already_filled = 0
                    
                elif(col == "followup"):
                    # new entry for the new followup question 
                    curr_folders = curr_folder.split()
                    for folder in curr_folders:
                        if folder[-1] == ';':
                            folder = folder[:-1]
                        if folder in raw_questions_to_hw:
                            raw_questions = raw_questions_to_hw[folder]
                            raw_questions.append(curr_question)
                            raw_questions_to_hw.update({folder : raw_questions})
                        else:
                            raw_questions = []
                            raw_questions.append(curr_question)
                            raw_questions_to_hw.update({folder : raw_questions})
                    curr_question = ""
                    curr_answer = ""
                    curr_folder = ""
                    endorsed = 0
                    already_filled = 0
                        
                    curr_follow_up = curr_follow_up + 1
                    curr_question = curr_text
                elif(col == "reply_to_followup"):
                    curr_answer = curr_answer + "\n" + curr_text
                    
num = 0
raw_questions_to_hw["hw5"] = [x for x in raw_questions_to_hw["hw5"] if x]
for i in raw_questions_to_hw["hw5"]:
    print(num)
    print(i)
    print('\n')
    num = num+1

# myDB.close()
# Out:
# Exception ignored in: <function Context.__del__ at 0x10355b950>
# Traceback (most recent call last):
#   File "/Users/maralevy/miniconda3/lib/python3.7/site-packages/zmq/sugar/context.py", line 46, in __del__
#     self.term()
#   File "zmq/backend/cython/context.pyx", line 136, in zmq.backend.cython.context.Context.term
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt
# Exception ignored in: <function Context.__del__ at 0x10355b950>
# Traceback (most recent call last):
#   File "/Users/maralevy/miniconda3/lib/python3.7/site-packages/zmq/sugar/context.py", line 46, in __del__
#     self.term()
#   File "zmq/backend/cython/context.pyx", line 136, in zmq.backend.cython.context.Context.term
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt
# Exception ignored in: <function Context.__del__ at 0x10355b950>
# Traceback (most recent call last):
#   File "/Users/maralevy/miniconda3/lib/python3.7/site-packages/zmq/sugar/context.py", line 46, in __del__
#     self.term()
#   File "zmq/backend/cython/context.pyx", line 136, in zmq.backend.cython.context.Context.term
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt
# 0
# my code wont compile because I removed the kudos problem on deque.ml becuase it had an error without me touching it; how many points will we lose for our code not compiling
#
#
#
# 1
# When will PAINT be released?
#
#
# 2
# After I implement rectangle and ellipse and run gdemo, I have a red square and red circle instead of a red square and a blue circle. Should this be concerning?
#
#
# 3
# I believe so
#
#
# 4
# How is fold_right any different from fold other than the placement of the last two arguments?
#
#
# 5
# What's the difference between calling Invalid_argument and failwith?
#
#
# 6
# The ellipse and rectangle are appearing in the wrong place, below where they are supposed to be. Is there something I'm doing wrong?
#
# Edit: Nevermind I fixed it
#
#
# 7
# I had the same problem. My rectangle is showing up in a different place. How did you fix this?
#
#
#
# 8
# All of the widgetTests for vpair are working, but I am not sure whether the repaint function is correct.
#
#
# 9
# When updating Paint.repaint for the draw_points method, how do we set the color in the graphics context if the graphics context is immutable?
#
#
# 10
# When I try calling my draw_points method in repaint, it says I have an unbound module. I have added draw_points to the gctx signature. What could be the issue?
#
#
# 11
# I am having a similar issue but I have not been able to find a syntax error apart from the one that comes when I try to call draw_points in repaint
#
#
# 12
# When converting the written code from hpairs to hlists, how do we account for how the hpairs are "broken up?"
#
# The instructions say that :
#
# list_layout hpair [w1;w2;w3;…;wn] is the same the as hpair w1 (hpair w2 (… (hpair wn-1 wn) …))
#
# but what if we have: hpair (hpair x y) (hpair (hpair (a b) c)...how would this be represented in list form when calling hlist?
#
#
# 13
# So there's no difference between: hpair (hpair x y) (hpair (hpair (a b) c)
#
# and
#
# hpair x (hpair (hpair y b) c)) ?
#
#
#
#
# 14
# My line preview works like normal except when I drag the mouse off the canvas and release the mouse outside of the canvas the preview line does not go away unless I click the canvas again. Is this normal behavior or does this mean there's a bug in my code?
#
#
# 15
# Do you want us to delete the Todo comments as we complete the homework?
#
#
# 16
# How do I test if my draw_point and draw_points functions are correct?
#
#
# 17
# Should completing task 1 change how the current application looks?
#
#
# 18
# For the handle in the checkbox widget, how should we check that someone clicked on the checkbox?
# Is it by::
#          pattern-matching the gctx.event that is passed in, if the event is MouseUp then change the value of the value_controller; for all other events don't do anything
#
#
# 19
# I tried it, but it doesn't seem to be changing the value in the value_controller, because the tests for clicking are failing.
#
#
# 20
# Codio isn't cooperating with me b/c it gives me all these red dots saying "unbound" module and I literally don't understand why any of these things aren't working.
#
# I then took "paint.ml" from the Homework Files and decided to try and "start clean" again but Codio then put red dots on the CLEAN file and I was shook...
#
# so is there anything I can do now? Any help would be appreciated.
#
# Thanks :)
#
#
# 21
# I've tried building and cleaning my project five times but the red dots still persist — the "clean" file that I downloaded from the HW5 webpage also responds poorly even after cleaning and stuff.
#
# Any more tips on how to proceed from here?
#
#
# 22
# I had a similar issue for my hw5 file. Logging out, clearing my cache and logging back in fixed it for me.
#
#
# 23
# I had the same issue where every instance of me using module or graphics or deque has an unbound module error. No other files of mine have any errors. I also tried cleaning rebuilding and clearing google chrome's cache after logging out to no avail. HELP!
#
#
# 24
# When I try to implement Widget.vlist in paint_widget, I end up getting two black rectangles on the screen when I run paint. When I leave in the original hpair code, the other implementations of Widget.hlist seem to be working fine, so I don't know why this is occurring.
#
# Also, should I be making a list of widgets first and then inputting that into Widget.hlist or Widget.vlist, or is there another way to implement that which is more efficient?
#
#
# 25
# but how do we make a list of widgets? and for the inputs of hlist- is the second input widget part of the list of widgets?
#
#
# 26
# i think i am having a similar problem with either vpair or vlist-- i see many black lines after i edit the layout, but both vpair and vlist passed all of the test cases. how can i trace my errors?
#
#
# 27
# I don't really understand which widgets were supposed to be making a list of? Are we supposed to be deleting the code for color_toolbar and implementing our own version of it?
#
#
# 28
# I have been trying to use fold_right on this but I can't seem to get it and I don't know why. Could you give any hints please?
# List.fold_right (fun x acc -&gt; pair x acc) ws space(0,0)
#
#
#
# 29
# Hello,
#
# I'm a little confused by the instructions:
#
# "You also need to modify the function associated with the Undo button to reset the paint.preview shape toNone. In addition, if the paint.mode is LineEndMode, then reset it to LineStartMode—this prevents strange behavior when the user starts drawing a line, drags the mouse off the canvas, and then clicks the Undo button."
#
# Should this last part also be implemented in the undo function?
#
#
# 30
# Hi! After I ran the gdemo after implementing the two functions in task 0, I got the circle and the rectangle, but both were in black. Is it supposed to be that way, or am I missing somethiing that I am supposed to implement?
#
# Thanks!
#
#
# 31
#
# My code looks like this right now (i did set the graphics state?), but it's still not updating the colors :(
#
#
# 32
# I don't understand why List.fold_right pair ws space (0, 0) does not suffice- I keep getting an error that pair is not the right type but I literally took it from the function header
#
#
# 33
# but fold would be for hlist and vlist, not for list_layout right?
#
#
# 34
# I'm not very clear on what exactly hlist and vlist does I understand that the difference in inputs into list_layout creates hlist and vlist but I'm not sure how to handle the pair input- am I supposed to use a higher order function? I already used List.fold_right in list_layout so that seems redundant
#
#
# 35
# When writing the function for draw_points, how can List.iter be called on a list when there's an additional argument being passed in between the call to draw_point and position list?
#
# (Instructions show: List.iter f [a1; ...; an] but in this case it looks like List.iter f g position list)
#
#
# 36
# nevermind, figured it out!
#
#
# 37
# How would I return the point value where MouseUp occurs?
#
#
# 38
# I'm really confused where we get the list of widgets to pass into list_layouts in Task 1. Do we just create a list? If so, what widgets do we put into the list?
#
#
# 39
# I am confused by what Graphics.js_mode entails. I cannot find a js_mode in the Graphics library, and I'm confused about what it would do.
#
#
#
#
# 40
#
# - Should this function be returning type widget and not gctx?
#
#
#
# - What is the type t? Should it be gctx? This type t also appears in a function in the Gctx module, so I don't know if its a typo or an actual type.
#
#
# 41
# Are the instructions directly underneath the header "Extending Shape Type" a separate set of instructions from those under "Updating Paint.paint_action" or are the latter explaining how to do the former (since both would have to be within paint_action)?
#
#
# 42
# I have implemented the paint_action function so that the mouse drag feature draws the line rather than the two clicks, but when I use it in the paint application, it seems like each line I draw takes longer to appear on the screen. I'm wondering if this is normal, or if I did something incorrectly in my implementation of paint_action...
#
#
# 43
# Also, when I implement preview, the line flickers while I drag it: is this normal?
#
#
# 44
#  have the same issue where the delay keeps getting worse and worse.
#
#
# 45
# I saw a previous question about "unbound module draw_points". I have an "unbound value draw_points" error in my paint.ml function as I am trying to add the Points (c, ps) to repaint. How can I fix this?
#
#
# 46
# Yes, I have an unbound value error, not unbound module.
#
#
# 47
# I am having the same problem. I think it is because the instructions say to use draw_points in repaint, but I can't because draw_points takes in a position list and the Points shape holds a point list.
# How do I make draw_points work for the Points shape if I can't change the headers of the functions?
#
#
# 48
# I updated undo for preview (I'm in task 2), but when I update repaint for preview and then try to draw a line, the preview is drawn as two lines very close together. When I don't update preview, everything seems to be functioning fine. Why exactly do I need to update repaint for preview if the preview feature works fine without the update to repaint?
#
#
# 49
# The instructions say this (below), but I never call repaint in my paint_action function, i just used draw_line and it worked without needing to change the repaint function from how it originally was.
#
#
#
#
# 50
# So when when it says to amend repaint, I don't actually have to edit that function for Task 2?
#
#
# 51
# I am having trouble figuring out how I should amend the function since paint.preview has type option. Can you give me a hint?
#
#
# 52
# I'm working on task 2, and so far my drag and drop seems to be half-working. now, i can only draw lines if i begin by dragging with the mouse, but I have to click again after releasing the mouse to end the line, instead of just being able to release the mouse for the line to appear. I've been reading through and I can't figure out where the problem with my logic is :( I'm wondering where in general I'm messing up
#
#
# 53
# I keep getting an error on gctx.ml file saying module Graphics is an alias for Module G, which is missing. How do I fix this?
#
#
# 54
# I have the same error message, and the only thing I have edited is the draw_rect function.  I'm pretty sure the error was there before I even began to edit the file.  How do I fix it?
#
#
# 55
# In the instructions, it tells us to use the fold_right function. Would we be using this along with anon. function? or can we just call list.fold_right on the list_layout arguments?
#
#
# 56
# I'm confused about what the following is trying to say. Don't we just create two variables x y and set them to the ocaml coords then plug in the other variables? What precaution should we have regarding using the native Ocaml function?
#
# Note that calling any native drawing method (such as Graphics.draw_rect) also requires conversion of the coordinates from our widget-local top-left-origin system to the bottom-left-origin system that the  Graphics library assumes.
#
#
# 57
# Is this change implemented automatically when we create widgets later? Or should we explicitly call a function to change the coordinates each time we add a widget?
#
#
# 58
# all of my tests for Task 1 pass the widgetTest file and I've modified color toolbar and mode toolbar to use Widget.hlist and modified paint_widget to use Widget.vlist but when I run paint the exact same layout occurs. is the problem in widget.ml or paint.ml?
#
#
# 59
# How come I can't see anything? I'm currently on Task 3. Did I miss some essential code in task 1/2?
#
#
#
#
# 60
# I'm not sure I understand what add_change_listener is supposed to do.  The instructions says it adds a new change listener function ('a -&gt; unit) to the value controller's list of change_listeners.
#
# I can't see a way to create/store a list of change_listeners given the types in the record. Since add_change_listener isn't mutable in the provided type code, it doesn't seem like we're supposed to update it with each call. (I did try to create a mutable field in make_control outside of the record, but it was fruitless..
#
# I also don't follow how it's supposed to listen for changes to the values without using a bool or a counter, but these don't seem like options given the make_controller framework provided.
#
# Would it be possible to clarify what add_change_listener does and how the functions are stored?
#
# In terms of the test, is t.contents is now a reference to v?
#
# ;; run_test "make_control change_listeners are triggered on set" (fun () -&gt; let vc = make_control 1 in let t = ref 0 in vc.add_change_listener (fun v -&gt; t.contents &lt;- v); vc.change_value 2; t.contents = 2)
#
# Thanks!
#
#
#
#
# 61
# So slightly different approach:
# while I get how to store stuff within the function generally, when I try to store add_change_listener, I end up storing ('a -&gt; unit) -&gt; unit as opposed to just the 'a -&gt; unit part.  I then am not sure how to separate and apply the 'a-&gt; unit part (I get the warning that it's a partial application).
#
# If I store add_change_listener to a  (('a -&gt; unit) -&gt; unit) list, how do I get the 'a -&gt; unit part?  Thanks for your help.
#
#
# 62
# *RESOLVED
#
#
# 63
# Screen_Shot_20181016_at_10.27.49_PM.png
#
# I'm a little confused by the compiler errors I'm getting. Everything seems to be working fine on codio (nothing underlined in red). I supplied int thicknesses in both the lightbulb and gdemo files. Also am I missing a file? Thanks!
#
#
# 64
# I'm still getting the errors. I tried cleaning and rebuilding and submitting again, but I'm still getting the same errors.
#
#
#
# 65
# For adding Points to the deque in paint_action, (Task 3, "Extending the Shape Type") how would I add a list of points? In other words, how would I get access to all the points that I pass when I am dragging my mouse?
#
#
# 66
# Whoops, I didn't see the instructions for doing this in action and repaint. Do all the tasks in "Updating Paint.paint_action" and "Updating Paint.repaint" complete what is explained in "Extending the Shape Type," not including making the constructor?
#
#
# 67
# I'm very confused about the checkbox. Could someone explain the concept, relating it to the button?
#
#
# 68
# Isn't the notifier button parallel to the value_controller in this sense?
#
#
# 69
# When I change paint_widget to use vlist there are large spaces in between my vertically arranged widgets. I'm not sure why since there are no spacer widgets in my list.
#
#
# 70
# I've been changing the y part of the size for vpair but nothing changes when I open Paint, why is this?
#
#
# 71
# When I run my drag and drop code for Task 2, I get double lines for all the lines in paint.shapes while I'm previewing, but then it goes back to normal when I release the mouse.
# while drawing first linewhile drawing second line
# after I am done drawing 2nd line
#
#
# 72
# I have this problem too, and I'm not calling repaint inside my paint_action.
#
#
# 73
# I'm also getting the double lines when previewing. I'm not calling repaint in paint_action either so I'm not sure what's wrong?
#
#
# 74
# I put in the following code for paint_action which returns unit, but I get the error shown below. Any reason as to why this is the case?
#
#
#
# 75
# Hm I put Some Line onto one line and tried all combinations of parentheses, but I still get the same error.
#
#
#
# 76
# Why does my paint GUI look like this?
#
#
#
# 77
# I'm not really sure why I'm getting the errors I'm currently getting for my implementation of the list_layout. I'm not sure if my anon function is incorrect, because I think I have the end part of fold correct, but it currently shows that my last two inputs for fold are not type checking.
#
# expression has type widget list but is expecting ((widget -&gt; widget) -&gt; widget) list
# and
# expression has type widget but is expecting widget -&gt; widget
#
#
#
# 78
# Should we be utilizing the same draw_ellipse function in gctx in task 0 and task 4?
#
#
# 79
# Would it be an acceptable solution to write a slightly modified ellipse function that takes in the arguments in a more clear way? For example, draw_box_ellipse that takes in two positions, corresponding to the bottom left and upper right corners?
#
#
# 80
# Are we allowed to just copy and paste the code you gave us in the second match of MouseDown and paste into MouseUp?
#
#
# 81
# This is similar to the post in @1434 but I do not understand how/where 'a value_controller stores a value and its list of change_listeners. Is 'a value_controller a record of three specific functions (as the instructions say) or does it contain a list of functions and a certain value...it seems to do both but how?
#
# Also,"Think carefully about what state needs to be stored with each instance of a value_controller returned by make_control" What does state mean in this context? Does it refer to the type state of paint.ml (shape, mode, color etc.)?
#
# Thanks!
#
#
#
# 82
# I'm getting a lot of errors with this message. How can I fix this?
#
#
# 83
# I want to see if I did task 0 correctly, but I get the error that The module Graphics is an alias for module G, which is missing.
#
# Nevermind, I was returning the wrong thing.
#
#
# 84
# I am having trouble understanding the last line of instruction on Task 3 where it tells me to set the color in the graphics context. Can you elaborate on this?
#
#
# 85
# How do you pass in c (color) on the right side of the points(c,ps) match case? I tried using with_params g c (just like how it was done in draw_line) but I get an unbound value error.
#
#
# 86
# I have read the instructions for Updating paint.paint_action several times and still can't figure out how to create a new shape Points (c, ps). What is the constructor for making a new shape?
#
#
# 87
# I just finished Task 1, and i when I ran paint, in order to see if i implemented the functions correctly, nothing shows up. It is just a blank window..any suggestions?
#
#
# 88
# So I got this to work, but I am not sure if I am doing this efficiently. Is there another more efficient way I should do this or is this ok?
# change_value =
#     (fun (v: 'a) -&gt; r.contents &lt;- v;
#     let rec loop (l : ('a -&gt; unit) list) : unit =
#       begin match l with
#       | [] -&gt; ()
#       | x :: xs -&gt; x v; loop xs
#       end
#     in loop cl_list.contents
#     )
# Like should I be creating my own recursive function loop or can I use List.iter or something?
#
#
# 89
# But how do you use List.iter if the list are the functions
#
#
# 90
# I know this has been asked before, but I checked my code over and over and I keep getting the unbound ____ error for almost everything and in every file. I didn't change anything in my code (and previously, it allowed me to run the paint program and have a pop-up and now I can't) and I don't have an extra semicolon anywhere. I also tried clearing my data and logging back out and in.
#
# Nevermind, I deleted a random line of text and added the line back and it suddenly worked again only in my paint.ml file but my gctx.ml still has the error
#
#
# 91
# Where is the Graphics library?
#
#
# 92
# For the last sentence of *Task 6 - Radio Buttons*, it says "creating any arbitrary group of radio buttons to control any arbitrary value(s)."I don't quite understand how a radio button can control any arbitrary value. Shouldn't a radio button only represent a boolean value (true or false)?Please give an example on radio buttons controlling arbitrary types other than bool.
#
#
# 93
# Whenever I draw an ellipse, it draws it and then all my widgets disappear and the program essentially just stops with the one drawn ellipse on the screen, I don't know what's wrong.
#
#
# 94
# I did handle the negative cases - it crashes as soon as I move the cursor from the final position after dragging.
#
#
# 95
# So I think my drag and drop function works. But as soon as we release the mouse button, should the line appear?
# For example, if I clicked down, drag my mouse over, and then release the mouse without moving at all, the line doesn't appear until I trigger another event (i.e. moving my mouse after releasing). So assuming I release the button at one position in the canvas, and stay at that position, should the line be shown? Or is it ok that the line is shown only when I trigger another event (i.e. move the mouse one pixel from the position I released the mouse click)?
#
#
# 96
# When creating some points and storing that to paint.preview, how do I actually pass in the position list to some points??
#
#
# 97
# How do we access an encapsulated function that is in a record?  More specifically, the functions in make_control
#
#
# 98
# Do we need the parentheses at the end?
#
#
# 99
# when I'm in point mode on paint, the color doesn't change when i draw the points. However, if I go on line mode and change the color and then come back to point mode, the color does change.
#
# my point state takes in the color, so I'm not sure what's wrong.
#
#
# 100
# Can someone point me in the right direction on what repaint should do for checkbox?
#
#
# 101
# Do size and repaint affect the outcome of the test cases? Or is that should handle
#
#
# 102
# when I'm drawing the ellipse in paint, the mouse stays at the center of the ellipse rather than at the corners. Any tips on fixing this?
#
#
# 103
# Can somebody help me figure out where the problem is with my handle for vpair?
#
# Thank you
#
#
# 104
# I changed it, but it is not working either?
#
#
# 105
# For list_layout why is it saying that the expression has 'a -&gt; 'b instead of widget even though we know that pair takes in widgets?
#
#
# 106
# Sorry to ask small questions again, but for "changing the toolbars to use vlist and hlist" after changing that in paint.ml is there something else i need to do? Because I'm still printing the same old line, rectangle, circle etc.
#
# Thank you
#
#
# 107
# Is there a built in function to find the absolute value of an integer in OCaml? I tried searching for one but had trouble finding it. Thanks!
#
#
# 108
# I'm having trouble adjusting the arguments in draw_ellipse to match the bounding box method. I'm confused because I would have expected ellipse to take in two positions, (1) the starting point (lower left) and (2) the ending point (upper right) but I see that it takes in a position at the center and the vertical and horizontal radii. Can you please offer some advice for thinking through this problem?
#
# Also, should I be doing the math assuming (0,0) is in the upper left, as opposed to the bottom left?
#
#
# 109
# Do we need to account when ellipse is drawn the other way ? Like clicked on the right side and dragged towards the left ?
#
#
# 110
# Should we comment when we add code in tasks other than 6? As an example, when we add the Point button, should we comment (*A point widget*)?
#
#
# 111
# Hi, I ran paint in my browser (Google Chrome) and it ran successfully in a pop-up window. However, when I click the quit button, nothing happens—I'm not sure if I accidentally messed up the code or if it has to do with an external factor. Is quit supposed to close the pop-up window?
#
#
# 112
# I am having trouble implementing the line preview in task 2 - the preview line is always black, and switched to the proper color after I move my mouse away. My code should be drawing the preview line with the color in the graphics context. In general, are there any pieces of this I am missing?
#
#
# 113
# I find myself unable to take advantage of make_control because whenever I want to use it I find myself needing to be able to reference the listeners func list in the widget handle in order to be able to execute the listeners on a value-changing event.
#
# For example, my radio button and checkbox implementations both work fine, but I find myself calling the listener functions inside of the widget handles. Is that the most "proper" way to implement these widgets. Because it seems haphazard that I'm basically copy and pasting make_widget just so the listeners list is in scope.
#
#
# 114
# I'm having a really hard time implementing the second part of change_value. The instructions say,
#     "It calls all of the change_listeners the value_controller has stored, with the newly set value as the argument to each."
# I'm trying to go through the list of change_listeners and apply the newly set argument to each using the List.iter function. However, I am struggling to write the function that needs to be passed into List.iter. The function needs to pass the argument into each element of the list, but I don't know how to do this without accessing each function in the list. I think I would need to write an anonymous function to pass into List.iter, but I have no idea how to illustrate that the argument v must be applied to every x of the list. Any advice would be much appreciated.
#
#
# 115
# When I run lightbulb, there is no pop up window. My pop up blocker is turned off and I'm using chrome.
#
#
# 116
# Still not working for me. It should function like the paint file, right? When you run lightbulb, it should display the lightbulb app web page, and then display another separate window for the actual lightbulb right?
#
#
# 117
# When I run lightbulb, I just get two black boxes. Is this supposed to happen? I have finished checkbox and make_control.
#
#
# 118
# After I draw the first ellipse, all of the others draw randomly when I just click. I am unable to change the center position and size for subsequent ellipses.
#
#
# 119
# In task 0 my ellipse and rectangle are in the correct location, however, the color of my ellipse is red when it should be blue.
#
#
# 120
# i'm having a similar problem except with the rectangle which is gray... my graphics context is set and i've refreshed twice. any other thoughts?
#
#
# 121
# If we choose to make the color sliders for task 6 (like the ones in the demo), should they respond to when a color_button is clicked (i.e, if someone clicks blue, should the blue slider go all the way up and the other two go all the way down), and if so, how can we go about implementing this?
#
#
# 122
# when i drag and drop to draw a line, it disappears as soon as I move my mouse. i'm not sure why this is happening.
#
#
# 123
# when the event pattern matches with MouseUp, I then pattern match "paint.mode" with LineEndMode p1, and add the line to shapes Deque through this code:
# Deque.insert_tail (Line (paint.color, p1, p)) paint.shapes;
# am I not supposed to insert the line into shapes Deque in the pattern match?
#
#
# 124
# Does it also make sense to do a coordinate conversion for the tuple dimension in draw_rect () in addition to position?
#
#
# 125
# Hi! I have been having trouble with compiling my project. When I click "Build Project," it gives me an error and a hint that
#
# Hint: Recursive traversal of subdirectories was not enabled for this build, as the working directory does not look like an ocamlbuild project (no '_tags' or 'myocamlbuild.ml' file). If you have modules in subdirectories, you should add the option "-r" or create an empty '_tags' file.
#
# I'm not sure what this means and if it was because of something I edited in the project files.
#
#
# 126
# I wrote a new draw ellipse function (draw_ellipse2) that implements the original draw ellipse function (draw_ellipse) but when I try to use it in my repaint function I get a unbound module error. Why isn't my function being registered?
#
#
# 127
# I implemented ellipse in a way that is similar to line and points (or so I thought), but when I click on the Ellipse button and then try to draw an ellipse, it doesn't draw anything and all of the toolbar and color widgets disappear.
#
#
# 128
# Now when I do it, the ellipses draw on the screen and the widgets don't disappear, but they show up in the top left corner and don't seem to be drawn correctly. I feel like this is something to do with graphics context, but I don't see why this would be any different for ellipse than for line or points.
#
#
# 129
# I am working on checkbox but I am really confused on how to structure the function/what syntax to use, I have complete make controller and use it in the function but I cant seem to understand where and how the record fields of the widget itself come into play.
#
#
# 130
# Somewhat, but I think I am more concerned with how the declaration of the record fields for the widget occur within checkbox
#
#
#
# 131
# I'm really stuck about how to implement fold.right in list_layout using the pair and ws inputs. I understand that pair is a function, and that it takes in two widgets to produce a new widget containing both of the original widgets. I've tried implementing fold with an anonymous function that takes in two widgets (the x and acc values for the widget list) and calls pair on both x and acc, but I get an type error that the function is expecting type 'a -&gt; 'b. When I try and implement fold without an anonymous function (by just passing in pair as the combine function) I get the same kind of error. Am I just misinterpreting fold_right?
#
#
# 132
# I had the same issue. Why did adding the parenthesis fix it? Also if space(0,0) was not of the "legal" type why was the error being shown for the pair function argument?
#
#
# 133
# I am currently coding the add_change_listener in make_control and I am try to update the list of change listeners by consing on the new element in the mutable record I used to store the change listeners. Codio says it won't typecheck since it's returning a list, but I'm trying to update the mutable contents of the record (which is a list) with an updated list. Shouldn't that return unit? Why doesn't this type check?
#
#
# 134
# You are setting x equal to y, correct? Sorry, I'm still a little confused why it doesn't type check
#
#
# 135
# How do we access the initial position in mouseup (since p is the position the mouse is at now)?
#
#
# 136
# Opened the file, edit nothing and unbound module alert?
#
#
# 137
# I would like to add a change listener such that whenever the value of the value controller is changed, it tells the widget to repaint itself. If add_change_listener is type bool -&gt; unit and the widget.repaint function is gctx -&gt; unit, how would I do this?
#
#
# 138
# I have everything working for checkbox except the fact that clicking the box doesn't repaint the box as black (it is originally painted as white to signify being unchecked). My checkbox consists of a colored square widget (that paints itself white if the vc's value is false and black if the vc's value is true) and with a label widget. Any idea on why it doesn't update the color of the color square when the vc's value changes?
#
#
# 139
# I implemented draw_rect and draw_ellipse, and I clicked build project and gdemo, but nothing is drawn.
# I wonder where goes wrong
#
#
# 140
# Can you take a look at line 134 in my paint.ml? I think I did everything as told but can't figure out the source of the warning. Thanks!
#
#
# 141
# For the undo function: if I drag the line off the canvas and click undo should it get rid of the previewed line and the line drawn before hand?
#
#
# 142
# I changed the state if LineEndMode, and am still getting the same error where it deletes 2 lines when I undo. I am supposed to implement this in the undo method correct?
#
#
# 143
# How does one get the color of a current graphics context? I am working on the paint_action function. Does one just use the color of the current pen through paint.color?
#
#
# 144
# I have implemented a drawing ellipses function but my ellipse expands from the center instead of using the bounding box method (even though that's what I tried to do). How can I fix this?
#
#
# 145
# | MouseDrag -&gt;      (begin match paint.mode with          | LineStartMode -&gt; paint.mode &lt;- LineEndMode p         | LineEndMode p1 -&gt; paint.preview &lt;- Some (Line (paint.color, p1, p))         | PointMode -&gt; let points =                        begin match paint.preview with                        | Some (Points (_, ps)) -&gt; ps                        | _ -&gt; []                        end in paint.preview &lt;- Some (Points (paint.color, p :: points))         | EllipseStartMode -&gt; paint.mode &lt;- EllipseEndMode p         | EllipseEndMode p1 -&gt; paint.preview &lt;- Some (Ellipse (paint.color, p1, p))        end)
# When I run paint to test my draw_ellipse, after I click the Ellipses button and then click and drag on the canvas, nothing happens on the canvas, but the buttons and the color labels disappear. Since nothing happens to the buttons when I simply click on the canvas, I'm guessing this is a problem with my MouseDrag event. However, I can't figure out the problem. What is the reason for this bug?
#
#
# 146
# Do I need to define the type for 'a value controller somewhere in my code before I write the make_control function or does OCaml already have it saved? (If so, where would be an appropriate place to add it?) Similarly, do I need to define a type for change_listener?
#
# In general, where should I be writing make_control. Can I just put it at the bottom of gctx.ml?
#
#
# 147
# Thank you! When try to write this function, I get errors on the words I am using to hold variables in the state record (for example, if I use "list" or "value" to hold state, codio says they are unbound values. Should I define a control_state type or something like it to tell ocaml which values I plan to put in the state?
#
#
# 148
# This question from above seems answered and I have trouble with it:
#
# Do I need to define the type for 'a value controller somewhere in my code before I write the make_control function or does OCaml already have it saved?
#
#
# 149
# It is said in the instruction that "make sure you are only passing positive values to these functions". Does this mean we need to check whether we are passing in positive values and make 0/negative values invalid?
#
#
# 150
# I am able to draw points in point mode every time I click, but I cant make a continuous stream of points when I drag the mouse.
#
# I understand that this is because I am SETTING paint.preview to be a given point instead of ADDING the point to paint.preview. But I don't understand how to ADD a point to paint.preview in MouseDrag.
#
#
# 151
# I set my preview to some line like this
#
# paint.preview &lt;- Some (Line (paint.color, p1, p)
#
# but I am getting an error that I do not understand.
#
#
# 152
# I added the pointmode, but when I went to test it my draw line no longer works. It won't let me do anything in the canvas even though I didn't change any of the start and end line mode code. Any ideas of what could be broken?
#
#
# 153
# Yeah I implemented both buttons and neither seem to be clickable, the default state for my paint.mode is set to line start mode though so I shouldn’t need to press a button
#
#
# 154
# Hello, I have managed to write the implementation for ellipse however there seems to be a bug that I cannot find. My program successfully draws ellipses however it is able to draw them outside of the "paint canvas". Where might I look to modify my code to restrict drawing of ellipses only to the canvas like the implementations of line and points.
#
# Thanks :)
#
#
# 155
# In what function do I implement the drag-and-drop feature for Task 2?
#
#
# 156
# When I try to hpair my checkbox, it turns out like this.
#
# Screen_Shot_20181018_at_2.15.06_PM.png
#
# any tips?
#
#
# 157
# I just have it at (0, 0)?
#
#
# 158
# What are we supposed to see if we've implemented Vpair correctly?
#
#
# 159
# Are we allowed to create new types, such as a thickness type?
#
#
# 160
# The comments before paint.ml's with_params functions say we should modify this function during task 5. However, the comments before repaint say we have to modify repaint in tasks 2, 3, 4 and maybe 6.
#
# Does this mean I cannot change the arguments of with_params, since I would have to update them in repaint? Or is this trivial and I can update arguments in repaint as needed?
#
# Thanks!
#
#
# 161
# The checkbox type given in the homework instructions is  "val checkbox : bool -&gt; string -&gt; widget * bool value_controller".
#
# However, we also need a label controller and notifier controller (I think? Let me know if this is wrong). If this is the case, are we supposed to use a different type signature for checkbox or does that imply we are extending upon a previous widget
#
#
# 162
# I implemented the thick lines, and it's working properly with the lines and ellipses, but for some reason my points are still thin when thick lines is on.
# Is there a problem with my code or is Graphics.plot just defined to be "immune" to the line width?
#
#
# 163
# Hello! I'm on task 1 changing toolbars section. My code compiled/passed the tests until the vlist and hlist, but my code for the last section returns an error.
# (** The color selection toolbar. Contains the color indicator and
#     buttons for several different colors. *)
#    let color_toolbar : widget = Widget.hlist [color_indicator; spacer;
#    color_button black; spacer; color_button white; spacer; color_button red;
#    spacer; color_button green; spacer; color_button blue; spacer;
#    color_button yellow; spacer; color_button cyan; spacer; color_button magenta]
#
# (** The top-level paint program widget: a combination of the
#     mode_toolbar, the color_toolbar and the paint_canvas widgets.
# *)
# (* TODO: Task 1 (and others) modify the layout to add new buttons and make *)
# (* the layout more aesthetically appealing.                                *)
#   let paint_widget =
#   Widget.vlist [paint_canvas; spacer; mode_toolbar; spacer; color_toolbar]
#
# For my last line of code, it returns that there is a syntax error and the code won't build. Also, for the color_toolbar, it says that color_button is unbound but I didn't change anything in color_button :( Could I get some help in fixing these errors? Thank you!
#
#
# 164
# I'm having trouble figuring out why my fold_right is causing the error I'm getting when I write pair w acc. What am I missing??
#
#
# 165
# Right now when I click my checkbox, all lines on the screen (both inside and outside of the canvas) change to/from thick lines. Any clue as to the source of my problem?
#
# Thanks!
#
#
# 166
# should we be using value_controller and make_control in a new slider widget?
#
#
# 167
# I'm finishing up task 3 right now and in neither the line mode nor point mode do my undo or color buttons work. I haven't changed the code for color or significantly changed undo so I'm not sure what's causing this problem.
#
#
# 168
# I am also having this problem. Why are my undo and quit buttons not working?
#
#
# 169
# My point button is working but my line button does not even though I was drawing lines earlier. I think *maybe* the lines I draw are being added to the paint.shapes because if for example I drag two streams of points and then draw two lines, if I click undo three times, it "does nothing" for the first two clicks and then undoes the most recent stream of points- is this because of my pattern matching in paint_action?
#
#
# 170
# After implementing task 3, and using paint.color to get the current selected color, the points don't change color when a different color is selected and new ones are drawn; they are always black in point mode unless I go to line mode and switch the color, and go back to points.
#
# Is paint.color the correct way to access the color still?
#
#
# 171
# I successfully implemented the checkbox function in gctx.ml and now I am trying to create a checkbox in paint.ml called "Thick Lines." However, my code is not compiling because I am saying that paint.mode becomes a wildcard on line 283 of paint.ml. What should I be changing the paint.mode to on that line?
#
#
# 172
# I fixed that issue but now I'm getting another error: "File "paint.ml", line 281, characters 45-58:Error: This expression has type string but an expression was expected of type bool"
#
# Not sure how to fix that
#
#
# 173
# I'm having trouble with add_change_listener. What I wrote adds a change_listener to a change_listener list, but the test case still fails. I don't know how i can make sure that the change_listener function being added can access change_value and get_value (because I'm guessing that's what needs to happen). Help!
#
#
# 174
# What value is a thick or thin line? Is this at our discretion?
#
# Also, what is the default line thickness?
#
#
# 175
# Does thickness have to be an int? I used a bool to differentiate two thickness.
#
#
# 176
# In task 4 I've coded the ellipse function using what I think is the bounding box method, but I'm not sure. I think the math is right, but when I draw the ellipse, the mouse stays in the upper left hand corner of the ellipse, so that feels wrong. I feel like the mouse should be in the upper right hand going through the ellipse, but no matter how I manipulate the code, I can't seem to get it to do that.
#
# Basically, is my task 4 correct for the bounding box method or is my math still wrong?
#
#
# 177
# I'm getting an unbound value for a function called with_thickness that I created. After building and cleaning the project, I have no other compilation errors in any other files. What could be wrong?
#
#
# 178
# let color_button (c: color) : widget =
#   let w,nc = colored_square 10 (fun () -&gt; c) in
#   nc.add_event_listener (mouseclick_listener (fun () -&gt;
#       paint.color &lt;- c ))
# Hello! I had an error for my code and the solution was to delete a semicolon that was at the end of this program (after the two closing parentheses). However, when I deleted that, a new error came up saying:
# "This operation has type unit but an expression was expected of type Widget.widget"
#
# I am unfortunately not at the part to work on color_button and have no idea how to solve this issue. Any help would be appreciated :((
#
#
# 179
# Jane the legend.. thank you
#
#
# 180
# I'm trying to call the functions/types I have written in Gctx in Paint. However, I am not able to do so without invoking Gctx.x ... I see that none of the other function/type calls need the Gctx prefix. What am I doing wrong? I have added the necessary stuff into the gctx.mli file
#
#
#
# 181
# in the gctx.mli file
#
#
# 182
# Do the sliders need to be draggable or is it okay to have them move by clicks?
# Also, do I need to have three color sliders or is having just one controlling the color's shade okay?
#
#
# 183
# It says this expression has type unit.
# this is not a function, it cannot be applied.
# Why? I can't think of what might be wrong
#
#
#
# 184
# I'm having difficulty understanding the parameters of list_layout () as they seem unnecessarily complicated. Is there an intuitive reason why it's structured in this way?
#
#
# 185
# Ok that helps a little, but the structure of fold_right is:
#
# val fold_right : ('a -&gt; 'b -&gt; 'b) -&gt; 'a list -&gt; 'b -&gt; 'b
#
# Whereas the function parameters are:
#
# (widget -&gt; widget -&gt; widget) -&gt; widget list -&gt; widget
#
# Are we not missing the very last parameter 'b to be able to use this function from the List Module?
#
#
#
# 186
# My checkbox is working (tested via lightbulb) and I have invoked the line width by using add_change_listener and have updated everything in my repaint and paint_action to account for thickness. However, the thickness is not changing when I click my checkbox. Is this something wrong with my value_controller?
#
#
# 187
# I create a function called checkbox that changes the thickness and passed it into my change listener
#
#
# 188
# So after I implemented task 2, it only draws a line when i click and drag, and if I don't drag it, the line would not be drawn (if i only click on 2 points, it doesn't give me a line like before). Is that how it's supposed to work?
#
#
# 189
# I don't think I see anything - so probably nothing?
#
#
# 190
# How do we know if we have accurately implemented the previewing portion of task 2?
#
#
# 191
# My paint pop up is blank after running it. Any reason why?
#
#
# 192
# What should a preview line look like?
#
#
# 193
# Any tips on how I should debug this? I don't know why it thinks I'm trying to make an int value_controller...
#
#
#
# 194
# nvm, i got it!
#
#
# 195
# When you draw a curve, if you undo, is it supposed to remove the entire curve? or is it supposed to remove segments of the curve at a time?
#
#
# 196
# Should the entire dragged line be removed (from MouseDown to MouseUp)?
#
#
# 197
# My undo button works, but after completing task 3, I can't draw any points. I can only draw lines. My quit buttons also does not work. How do I fix this problem?
#
#
# 198
# I believe so. My quit button doesn't work also and that was given to us.
#
#
# 199
# I was trying to get the radii for the ellipse in the paint_action function. How should I convert the position  (p  = event_pos event gc) into in*int so I can calculate the radii?Thank you!
#
#
# 200
# Are point/points not supposed to be able to be thicc-ified?
#
#
# 201
# But the set_line_width documentation states that it will "Set the width of points and lines drawn with the functions above."
#
# Does this still mean we don't need to change thickness of points in our implementation? I know in practice you can't even see the difference anyways but still wondering
#
#
# 202
# When I try to implement the generic helper function (make_control), I keep getting a syntax error that says I have an unbound record field for add_change_listener. I basically have { add_change_listener = "rest of the code"...}. Is there a reason why I keep getting this error?
#
#
# 203
# I think that solved the first problem but also resulted in the entire expression change_value now having type unit instead of type 'a -&gt; unit. Do you have any guidance on how to fix this issue?
#
#
# 204
# I am having a problem, that each time I draw an ellipse, no matter where I click, it takes in the first point to be (0,0) and makes the ellipse with that as the first corner. How can I fix this?
#
#
# 205
# Would a redo feature be considered a valid choice for task 6?
#
#
# 206
# there are a lot of places that say I will need to change them in Task 2 but is that necessary? for example, I can't really imagine why I would need to change
#
# type shape =
#   | Line of color * point * point
#
#
#
# 207
# I finished task 1 and all the tests are passing. However, when I run paint, it looks like:
#
#
#
# I don't know why there is a big margin below each widget...
#
#
# 208
# When I am in "preview mode" (aka) dragging my mouse around, then I move my mouse outside the canvas and unpress my mouse, the line stays. Also when I move my mouse back over the canvas it still tracks my mouse though I am not dragging which clearly breaks the program. Can I get a hint at how I can fix this?
#
#
# 209
#
# I didn't modify anything on line 223, but I somehow have a compile error? How would I fix this? Thank you!
#
#
# 210
# I implemented the button for Points under Task 3 and it appears on the paint application.  However, whenever I press it on the paint application, the mode doesn't switch.  Is there something I'm doing wrong or should I come to office hours?
#
# let w_points, lc_points, nc_points = button "Point"
#
# ;; nc_lines.add_event_listener (mouseclick_listener ( fun () -&gt; (paint.mode &lt;- PointMode; paint.preview &lt;- None )))
#
#
# 211
# I'm on question 6 and I have created a slider for the thickness. Like the instructions suggested the slider will only adjust the thickness of the line if the thick checkbox is checked. However I have encountered one little issue that I am not sure if I need to fix: when I check the thick checkbox, I have a default thick value; if the slider is adjusted before I check the checkbox, the lines are drawn with the default thick value instead of the slider thick value. Is this ok? It only works if you adjust the slider after you check the checkbox.
#
#
# 212
# ...
#
#
#
# 856
# I know this is not a necessary feature for the assignment, but I am trying the adjust the values of my rgb sliders so that when I use the color buttons, the values of the sliders adjust. This seems like it would be a simple change of the slider values to the rgb of the new color, but I don't know how to externally change the slider values since I can't access the value controllers outside of the sliders themselves.
#
#
# 857
# Should I have implemented slider with a notifier controller, or is this possible to do with simply a value controller and widget? I tried adding a change listener that changed the value stored in the slider, but I dont think this is updated because clicking the color buttons is an event outside the slider. I thought about calling either repaint or handle for the sliders inside the color button, but they both require a gctx input...
#
#
# 858
# In the style guide, it says that commenting above your code is preferred. However, in the homework, there are some pre-written comemnts that come AFTER the code. Should we change that? Should our own comments go above the function or follow those comments for consistency?
#
#
# 859
# I am trying to create the slider widget in the paint file similar to how I did checkbox, but it is saying that my slider function is unbound. I checked to see if I passed in checkbox somewhere else in the files, but it isn't called anywhere other than where the widget is formed.
#
#
# 860
# In paint.ml it says my slider function (which I wrote in widget) is an unbound value. Is there somewhere else in my code I should've implemented slider in order to use it in paint?
#
#
# 861
# Will our layouts for the toolbar be graded or is it just for fun? I.e., make it look pretty with borders and stacking sliders/buttons
#
#
# 862
# When I try to submit my project I get a compiling error on gdemo.ml saying the draw_ellipse function took intoo many arguments even though running gdemo works fine. I didn't change anything in gdemo.ml so I think it's a bug with OCaml. What do I do regarding submitting the project?
#
# edit: never mind, please disregard
#
#
# 863
# When I am in PointMode and start dragging from outside the canvas and then go onto the canvas, points are drawn on the canvas. I had the same issue with lines, but lines have LineStartMode and LineEndMode, so I could make sure that LineEndMode only happened when LineStartMode happened after MouseDown. I can't handle this issue in the same way because there is not PointStartMode and PointEndMode, so how can I make sure that PointMode only happens when MouseDown happened within the canvas?
#
#
# 864
# Hi, my slider now can only allow me to click once which will fill out the whole bar. However, before I added "(Gctx.with_color g c)" in the slider function, I was able to drag (just the color was wrong since it was black). I did not modify anything else. Any suggestions for what's causing this problem? Thanks!
#
#
# 865
# Ohh yes it should be min of 255 and fst p. Thanks!!
#
#
# 866
# In my red color slider, I want to update the paint.color to a record {r,g,b} where g and b are the current values of paint.color and r is the new value determined by the slider.  I understand how to update the r value, but how do I access the current b and g values? I tried something like paint.color.g but that does not work.
#
#
# 867
# I tried to use my radio boxes function for the first time and all of a sudden i am getting lots of unbound module dots throughout paint.ml...i can't figure out why they are popping up. Any ideas?
#
#
# 868
# My thickness slider works, so the lines will change thickness when I drag a long the slider, but the rectangle within the slider does not move with my mouse. Does this stem form a problem in my widget code?
#
#
# 869
# How do I make it so if I click the slider, the checkbox for thick lines is automatically filled?
#
#
# 870
# My thickness slider continues past the bounds of my box. How do I fix this?
#
#
# 871
# messed up a lot of stuff in my code by undoing. Don't know how to go back to the last point where i zipped the code. kinda an emergency
#
#
# 872
# Can we use a rectangle as an indicator instead - see below
#
#
#
#
# 873
# Do we need to display on the GUI a number value for the thickness of the line if we are creating a slider that allows you to toggle the thickness of the line? Like display 5 somewhere if the width\thickness of the line is 5?
#
#
# 874
# for my color slider widgets I keep getting an error of unbound value?
# let (widget_red, vc_red, _) = color_slider (red, 0)
#
#
#
# 875
# Is there any way I can access my edit history through codio?
#
#
# 876
# None of why buttons work when I click on them and I cannot figure out why. The buttons that were given (Undo, Quit) do not work either. What can be the problem?
#
#
# 877
# Whats the best way to implement borders around buttons? Mine aren't showing up for some reason even after calling the border function on a created button with an hpair.
#
#
# 878
# So in trying to implement the thickness checkbox in paint.ml I'm running into weird errors. So my goal here is to reverse the state of the value inside the checkbox's value controller. So what I want to do is is perform a unit-&gt;unit action when the mouse is clicked. So I created a helper function which by design is of type unit to unit. This is not bringing up any errors. But when I try to make it a input in mouseclick listener I keep on the getting the error "Expr is of type unit but was expecting unit -&gt; unit". What am I doing wrong here?For reference,  tw_vc is the value listened for the thickness widget checkbox.
# let unit_to_unit():unit =	let k:bool = not(tw_vc.get_value()) in	tw_vc.change_value(k) 	in			mouseclick_listener(unit_to_unit())
#
#
# 879
# My slider widget doesn't work when I drag my mouse on it, but works if I drag my mouse slightly under it. What could be the reason for that?
#
#
# 880
# So I have implemented a thickness slider by adding a new int state but for some reason, I cannot get it to work. Is there any way to fix it?
#
#
# 881
# So I have a type bool thickness and int thickness_number. When the bool is true, the int_thickness is applied. I am passing everything back to gctx where this occurs in the function set_graphics_state. For some reason I cannot suss out the issue.
#
#
# 882
# When I add a thickness argument to with_params function for task 5, it tells me that the constructior thickness does not exist. However I defined thickness type in gctx file and in its interface.
#
# What can be wrong?
#
#
# 883
# I submitted my hw which worked fine, and now that I went back to correct the style, the program is not compiling anymore, and it is not recognizing most of the types from other files. What is the problem?
#
#
# 884
# and lot of errors say that module G is missing
#
#
# 885
# I don't understand what the handle function is supposed to be doing or how it would even work.
#
# So the handle function takes in a graphics context and event but we presumably have to call add_change_listener to do something. I just don't see how to get from A to B here. Also I don't understand what the function of a change listener is (isn't it detecting a mouse click, so something to do with mouseclick_listener?) or why we would need to store multiple such change listener functions.
#
# I'm so confused.
#
#
# 886
# I want to pass in a mouseclick_listener into add_change_listener but the types don't match....
#
#
# 887
# Hi, in the following code I'm getting the error " Syntax error after unclosed (, expecting ')' " on the very last else statement. I've gone to office hours and still can't seem to find the source. Help?
#
# repaint =
#   (
#   fun (g: Gctx.gctx) -&gt;
#         let width = 2 in
#         let height = 2 in
#         Gctx.draw_rect g (0,0) (width,height); (*draw the square regardless of state*)
#         Gctx.draw_string g (width + 1, 0) s;   (*draw the string regardless of state*) (*does this have to be a label???*)
#         if checkbox_state.get_value()
#         then (*draw check on box*)
#         Gctx.draw_line g (0,0) (width,height);
#         Gctx.draw_line g (width,0) (0,height);
#         else () (*do not draw checkmark*)
#    );
#
#
#
# 888
# That did not fix the issue.
#
#
# 889
# Can I get a bump on this? I sat in office hours for 2 straight hours and neither I or either of the TAs had a solution to this bug. Additionally both suggestions posted on this thread don't work. I didn't even come close to completing Task 5 because of this.
#
#
# 890
# This bug prevented me from even moving on to testing the check box functionality. I sat in office hours staring at this for 2 hours and so far no suggestions have helped. I didn't complete Task 5 because of this.
#
#  " Syntax error after unclosed (, expecting ')' " on the very last else statement
#
# repaint =
#   (
#   fun (g: Gctx.gctx) -&gt;
#         let width = 2 in
#         let height = 2 in
#         Gctx.draw_rect g (0,0) (width,height); (*draw the square regardless of state*)
#         Gctx.draw_string g (width + 1, 0) s;   (*draw the string regardless of state*)
#         if checkbox_state.get_value()
#         then (*draw check on box*)
#         Gctx.draw_line g (0,0) (width,height);
#         Gctx.draw_line g (width,0) (0,height);
#         else () (*do not draw checkmark*)
#    );
#
#
#
#
#
# 891
# Thanks that worked. I don't know why but it did.
#
#
# 892
# Now on to handle in checkbox. MouseUp is saying unbound constructor. I checked Gctx.mli and Gxtx.ml and it's there in both... Why would it be saying unbound?
#
# handle =
#     (
#     fun (g: Gctx.gctx) (e: Gctx.event) -&gt;
#     begin match e with
#       | MouseUp -&gt; let trueorfalse = checkbox_state.get_value in
#                   checkbox_state.change_value (not trueorfalse);
#       | _ -&gt; ()
#     end
#
#     );
#
#
#
# 893
# If I say Gctx.MouseUp I just get a different error. Now it's "This pattern matches values of type Gxtx.event_type but a pattern was expected which matches values of type Gctx.event = Gctx.event_type * Gctx.position.
#
#
# 894
# Ok so I don't really understand why checkbox would be passing one of the click tests but not the other two.
#
# Here is my full checkbox:
#
# let checkbox (init: bool) (s: string) : widget * bool value_controller =
#   let checkbox_state = make_control init in
#   ( (*tuple start*)
#   {repaint =
#   (  fun (g: Gctx.gctx) -&gt;
#         let width = 2 in
#         let height = 2 in
#         Gctx.draw_rect g (0,0) (width,height); (*draw the square regardless of state*)
#         Gctx.draw_string g (width + 1, 0) s;   (*draw the string regardless of state*) (*does this have to be a label???*)
#         if checkbox_state.get_value ()
#         then  (*draw check on box*)
#         (Gctx.draw_line g (0,0) (width,height);
#         Gctx.draw_line g (width,0) (0,height);)
#         else ()  (*do not draw checkmark*)
#    );
#
#     handle =
#  ( fun (g: Gctx.gctx) (e: Gctx.event) -&gt;  (*what do i use the Gctx.gctx for????*)
#     let click = Gctx.event_type e in
#     begin match click with
#       | Gctx.MouseUp -&gt; let trueorfalse = checkbox_state.get_value () in
#                   checkbox_state.change_value (not trueorfalse);
#                (*   checkbox_state.add_change_listener(some function ); *)
#       | _ -&gt; ()
#     end
#
#     );
#
#     (*string has to go into a label??*)
#     size = (fun () -&gt; Gctx.text_size s)}
#
#   , checkbox_state) (*tuple end*)
#  This seems like an issue with handle? But I thought that this method of changing the value would be sufficient. Do I also need to call add_change_listener somewhere? To add some kind of change_listener ...  but I don't understand why that's necessary or what to even put in it.
#
#
# 895
# also I when I run lightbulb, the state light and listener light appear next to black squares but nothing else (isn't my checkbox supposed to show up??) and when I click anywhere nothing happens.
#
#
# 896
# I'm confused about where to update the value of the checkbox with a new thickness. I managed to implement the checkbox into paint and clicking on it in the tool bar will toggle whether or not it's checked but nothing happens because I never update the thickness. I have no idea where or how I'm supposed to do this.
#
#
# 897
# The value in the value controller changes whenever you click. Should I be adding a mouse click listener via add_change_listener?
#
# I have something like this
#
# ;; changeThickness.add_change_listener (mouseclick_listener (fun () -&gt;      let check_state = w_thickness.get_value () in      if check_state then paint.thickness &lt;- thick else () ) )
#
# but it's giving me all kinds of errors. Additionally I don't know what function I actually want to call to set the line width.
#
#
# 898
# bump
#
#
# 899
# I don't even know where to start with the slider widget. Should it return an int controller? Just considering repaint, I currently have something like
#
# repaint =
#   (  fun (g: Gctx.gctx) -&gt;
#        (*draw the slider line regardless of state*)
#         Gctx.draw_line g (0,0) (0,line_height);
#         Gctx.draw_line g (0,line_height) (line_width,line_height);
#         Gctx.draw_line g (line_width, line_height) (line_width, 0);
#         Gctx.draw_line g (line_width,0) (0,0);
#         (*draw the sliding rectangle depending on state*)
#         let x =  slider_state.get_value () in
#         (Gctx.draw_rect g (x,0) (slider_box_w,slider_box_h);)
#    );
# Is my controller supposed to be of type int where I pass in the x values and it updates based on where the user is dragging the mouse?
#
# How on earth is this supposed to happen. My handle is the following but it doesn't feel right at all.
#
# handle =
#  ( fun (g: Gctx.gctx) (e: Gctx.event) -&gt;  (*what do i use the Gctx.gctx for????*)
#     let click = Gctx.event_type e in
#     begin match click with
#       | Gctx.MouseDown -&gt; let x = slider_state.get_value () in
#                   slider_state.change_value (x); (*get x and then change x???? feel like i'm missing a step*)
#       | _ -&gt; ()
#     end
#     );
#
#
#
#
# 900
# I think I should be storing the x position of the mouse cursor in the value controller. I currently have the following in my handle but I don't know if this is a valid way of doing this. Furthermore the line
# let xpos = fst pos in
# gives an error with pos underlined as "expression is Gctx.gctx -&gt; position but expression of type 'a * 'b expected"
#
# handle =
#  ( fun (g: Gctx.gctx) (e: Gctx.event) -&gt;  (*what do i use the Gctx.gctx for????*)
#     let click = Gctx.event_type e in
#     let pos = Gctx.event_pos e in
#     let xpos = fst pos in
#     begin match click with
#     (*how do I get the mouse coordinate to add to the int value controller? *)
#       | Gctx.MouseDown -&gt; (slider_state.change_value (xpos);)
#       | Gctx.MouseDrag -&gt; (slider_state.change_value (xpos);)
#
#       | _ -&gt; ()
#     end
#     );
# Should I be storing the mouse x coords here and does this account for the dynamic updating when you're trying to drag the slider?
#
#
# 901
# The return type of Gctx.event_pos e should be a position which is tuple of type int * int. Which is why I named the variable pos and why I thought I could extract the first value from it. I don't undestand why Gctx.event_pos e would be returning the function and not the actual tuple.
#
#
# 902
# Since I'm already comfortable with codio, I was thinking of sticking with that. But would it be worth my while to switch to eclipse?
#
#
# 903
# Can we use the weighted average function given to us in the alphablend function?
#
#
# 904
# In Pixel, all the methods after the constructors require us to reference the instance variables. How do we access these? Something like this.pixel. How can we reference the the red/green/blue values? The int[] we create in the constructor is only available inside the constructor method.
#
#
# 905
# To be briefer with my question, are we allowed to add instance variables to the pixel class?
#
#
# 906
# I'm running the GUI and when I rotate the image (with the rotatecw code) it all turns to a bluish/navy color. Is there something wrong with my Pixel class?
#
#
# 907
# if this helps, the orientation is completely correct, just not the color
#
#
# 908
# My submit page still showed HW5 point as 0. Are we getting our grade on GUI back before midterm?

# %%
# This cell runs TF-IDF using the Stack Exchange Archives and then shortens
# all questions to 25 words so that they are prepared for BURT


# Just using questions for right now
    
# contentless words ('the', 'a')
from nltk.tokenize import word_tokenize
import string

stop_words = ["ourselves", "hers", "between", "yourself", "but", "again", 
                  "there", "about", "once", "during", "out", "very", "having", 
                  "with", "they", "own", "an", "be", "some", "for", "do", "its", 
                  "yours", "such", "into", "of", "most", "itself", "other", "off",
                  "is", "s", "am", "or", "who", "as", "from", "him", "each", "the",
                  "themselves", "until", "below", "are", "we", "these", "your", "his", 
                  "through", "don", "nor", "me", "were", "her", "more", "himself", "this",
                  "down", "should", "our", "their", "while", "above", "both", "up", "to",
                  "ours", "had", "she", "all", "no", "when", "at", "any", "before", "them",
                  "same", "and", "been", "have", "in", "will", "on", "does", "yourselves", 
                  "then", "that", "because", "what", "over", "why", "so", "can", "did", 
                  "not", "now", "under", "he", "you", "herself", "has", "just",
                  "where", "too", "only", "myself", "which", "those", "i", "after",
                  "few", "whom", "t", "being", "if", "theirs", "my", "against", "a",
                  "by", "doing", "it", "how", "further", "was", "here", "than", "ok",
                  "thank", "ah"]

length = len(raw_questions_to_hw["hw5"])
shortened_questions = []
for i in range(0, length):
    question = raw_questions_to_hw["hw5"][i]
    tokens = word_tokenize(question)
    tokens = [w.lower() for w in tokens]
    words = [w for w in tokens if (not w in stop_words and w != "" and w != " ")]

    # Get rid of punctuation
    table = str.maketrans('', '', string.punctuation)
    words = [w.translate(table) for w in words]

    final_question = " ".join(words)

    shortened_questions.append(final_question)

#     shortened_questions = [s for s in raw_questions if s != '']

    # Printing out average
totalNumWords = 0
maxLength = 0
for s in shortened_questions:
    numWords = len(word_tokenize(s))
    if (maxLength < numWords): 
        maxLength = numWords
    # print(numWords)
    if (numWords > 50):
        print(s)
        print("\n")
    totalNumWords += numWords

print("AVERAGE " + str(totalNumWords/len(raw_questions_to_hw["hw5"])))
print("MaxLength " + str(maxLength))
print("Length " + str(len(shortened_questions)))
print("Length " + str(len(raw_questions_to_hw["hw5"])))
# Out:
# m sure understand addchangelistener supposed  instructions says adds new change listener function     gt  unit  value controller s list changelisteners  ca nt see way createstore list changelisteners given types record  since addchangelistener nt mutable provided type code  nt seem like re supposed update call   try create mutable field makecontrol outside record  fruitless also nt follow s supposed listen changes values without using bool counter  nt seem like options given makecontroller framework provided  would possible clarify addchangelistener functions stored  terms test  tcontents reference v    runtest  makecontrol changelisteners triggered set   fun     gt  let vc  makecontrol 1 let  ref 0 vcaddchangelistener  fun v   gt  tcontents  lt   v   vcchangevalue 2  tcontents  2  thanks
#
#
# think drag drop function works  soon release mouse button  line appear  example  clicked  drag mouse  release mouse without moving  line nt appear trigger another event  ie  moving mouse releasing   assuming release button one position canvas  stay position  line shown  line shown trigger another event  ie  move mouse one pixel position released mouse click
#
#
# find unable take advantage makecontrol whenever want use find needing able reference listeners func list widget handle order able execute listeners valuechanging event  example  radio button checkbox implementations work fine  find calling listener functions inside widget handles   proper  way implement widgets  seems haphazard m basically copy pasting makewidget listeners list scope
#
#
# m really hard time implementing second part changevalue  instructions say   calls changelisteners valuecontroller stored  newly set value argument   m trying go list changelisteners apply newly set argument using listiter function  however  struggling write function needs passed listiter  function needs pass argument element list  nt know without accessing function list  think would need write anonymous function pass listiter  idea illustrate argument v must applied every x list  advice would much appreciated
#
#
# m really stuck implement foldright listlayout using pair ws inputs  understand pair function  takes two widgets produce new widget containing original widgets  ve tried implementing fold anonymous function takes two widgets  x acc values widget list  calls pair x acc  get type error function expecting type    gt   b  try implement fold without anonymous function  passing pair combine function  get kind error  misinterpreting foldright
#
#
#  mousedrag   gt   begin match paintmode  linestartmode   gt  paintmode  lt   lineendmode p  lineendmode p1   gt  paintpreview  lt    line  paintcolor  p1  p    pointmode   gt  let points  begin match paintpreview   points    ps     gt  ps     gt    end paintpreview  lt    points  paintcolor  p   points    ellipsestartmode   gt  paintmode  lt   ellipseendmode p  ellipseendmode p1   gt  paintpreview  lt    ellipse  paintcolor  p1  p   end  run paint test drawellipse  click ellipses button click drag canvas  nothing happens canvas  buttons color labels disappear  since nothing happens buttons simply click canvas  m guessing problem mousedrag event  however  ca nt figure problem  reason bug
#
#
# hello  m task 1 changing toolbars section  code compiledpassed tests vlist hlist  code last section returns error    color selection toolbar  contains color indicator buttons several different colors    let colortoolbar  widget  widgethlist  colorindicator  spacer  colorbutton black  spacer  colorbutton white  spacer  colorbutton red  spacer  colorbutton green  spacer  colorbutton blue  spacer  colorbutton yellow  spacer  colorbutton cyan  spacer  colorbutton magenta    toplevel paint program widget  combination modetoolbar  colortoolbar paintcanvas widgets      todo  task 1  others  modify layout add new buttons make     layout aesthetically appealing    let paintwidget  widgetvlist  paintcanvas  spacer  modetoolbar  spacer  colortoolbar  last line code  returns syntax error code wo nt build  also  colortoolbar  says colorbutton unbound nt change anything colorbutton   could get help fixing errors
#
#
# task 4 ve coded ellipse function using think bounding box method  m sure  think math right  draw ellipse  mouse stays upper left hand corner ellipse  feels wrong  feel like mouse upper right hand going ellipse  matter manipulate code  ca nt seem get  basically  task 4 correct bounding box method math still wrong
#
#
# let colorbutton  c  color   widget  let w  nc  coloredsquare 10  fun     gt  c  ncaddeventlistener  mouseclicklistener  fun     gt  paintcolor  lt   c   hello  error code solution delete semicolon end program  two closing parentheses   however  deleted  new error came saying   operation type unit expression expected type widgetwidget  unfortunately part work colorbutton idea solve issue  help would appreciated
#
#
#  event handling  gctxml  m receiving strange error  right type eventtype defined  says  syntax error  expecting in    nt made changes gctxml besides drawrect drawellipse   upon build  says  rm rf gml cp gjsmlx gml ocamlbuild useocamlfind pkg jsofocaml pkg jsofocamllwt pkg jsofocamllwtgraphics gdemobyte  ocamlfind ocamldep package jsofocamllwtgraphics package jsofocamllwt package jsofocaml modules gctxml  gt  gctxmldepends file  gctxml   line 224  characters 04  error  syntax error command exited code 2  hint  recursive traversal subdirectories enabled build  working directory look like ocamlbuild project  tags  myocamlbuildml  file   modules subdirectories  add option  r  create empty tags  file  enable recursive traversal subdirectories  use following tags  file  true  traverse  traverse compilation unsuccessful building 9 targets  8 cached  000000 make    gdemobyte  error 10 codio  nobodylazarus  workspace
#
#
# reason  gctxml throws syntax error  even though thing modified drawrect drawellipse  saw previous post error nt able determine source problem  could problem  file  gctxml   line 223  characters 04  error  syntax errorcommand exited code 2hint  recursive traversal subdirectories enabled buil working directory look like ocamlbuild project  tags  myocamlbuildml  file   modules subdirectori add option  r  create empty tags  file  enable recursive traversal subdirectories  use following tags  file  true  traverse  lt  dir1  gt   lt  dir2  gt   traverse
#
#
# added gctx functions  let thicken  g  gctx   gctx   g linethickness  8  let thin  g  gctx   gctx   g linethickness  2  also added gctxmli file   produce new gctx thick line width   val thicken  gctx   gt  gctx   produce new gctx thin line width   val thin  gctx   gt  gctx called thicken paintml got unbound value error
#
#
#   produce new gctxt different pen color   let withcolor  g  gctx   c  color   gctx   g color  c  found function given code  would function way set new color graphics context  technically creating duplicate color changed  since color immutable field gctx  also  nt quite exactly remember learned    could pointed place lecture notes functionality explained
#
#
#  dropdown menu widget widgetml  using functions gctxml   use paint choose different types dotted lines  nt think animate dropdown  repaint method based boolean value tells whether menu open  although see similar radio button apart fact saves space  see implementation pretty challenging might require two value controllers  one option menu chosen another whether menu open  would also consider situation dropdown   features  ll attempt radio buttons sliders first implement time
#
#
# finally  mouse release event  gctxmouseup  detected  user stopped dragging mouse draw points  case  following  extract list points paintpreview  value present  clear previewif list points empty  insert points shape deque   would nt make sense insert empty shape deque  since would waste space   understanding instructions correctly  first checking value present paintpreview  none  checking  something  whether list points  ps  empty  would require two patternmatches  also  extracting list points shape points  c  ps   case  would know color pick insert points shape deque
#
#
# let repaint  g  gctx   unit  let drawshape   shape   unit  begin match  line  c  p1  p2    gt  drawline  withparams g c  p1 p2  points  c  ps    gt  gctxdrawpoints  withparams g c  ps end given code  inside pattern match starting line  c  p1  p2    calling drawline inside paintml  drawline function defined gctxml  wondering works whether could drawpoints instead gctxdrawpoints
#
#
# let slider  init  int   widget  int valuecontroller  let initcon  makecontrol init   repaint   fun  g  gctxgctx    gt  gctxdrawrect g  00   2510   gctxfillrect g  00    min 0  initcongetvalue     10    handle   fun  g  gctxgctx   e  gctxevent    gt  let  mousex  mousey   gctxeventpos e g begin match  gctxeventtype e   mousedown   gt      mousedrag   gt  initconchangevalue    min mousex 25  25  initcongetvalue     mouseup   gt  initconchangevalue    min mousex 25  25  initcongetvalue        gt     end   size   fun     gt   2510      initcon  get errors saying mousedown  mousedrag  mouseup visible current scope
#
#
# let makecontrol  v      valuecontroller  let stateval   ref   contents  v  let statecl   ref   contents      addchangelistener   fun x   gt   stateclcontents  lt    x   stateclcontents    statevalcontents  lt   v   getvalue   fun     gt  statevalcontents   changevalue   fun x   gt   statevalcontents  lt   v    listiter  fun x   gt     stateclcontents    know code pretty far supposed  read previous posts  lecture notes  slides  faq s still nt feel like understand define records  ca nt get past error x   stateclcontents  either  based code  m missingmisunderstanding
#
#
# much  using format notifier function s use listiter  changed implementation listiter  let makecontrol  v      valuecontroller  let stateval   contents  v  let statecl   contents      addchangelistener   fun x   gt   stateclcontents  lt    x   stateclcontents     getvalue   fun     gt  statevalcontents   changevalue   fun x   gt   statevalcontents  lt   v    listiter  fun x   gt  x v  stateclcontents    unfortunately  still passing third makecontrol test  must still applying  fun x   gt  x v  incorrectly  format  point different example   function applying listiter
#
#
# type shape   line color  point  point  points gctxcolor  point list  elipse color  point  point given code file  line defined color  point  point  task 3  however  says descriptions points gctxcolor  bit confused nuance wondering case  guess probably color field gctx type also type defined gctx  additional question  tasks 3 4 paintaction  store preview shape color attribute paintcolor instead gccolor  could nt done returned error   nt color current graphics context  bit confused graphics context s color interacts paint state s color
#
#
# nt completely understand instructions  finally  mouse release event  gctxmouseup  detected  user stopped dragging mouse draw points  case  following  extract list points paintpreview  value present  clear previewif list points empty  insert points shape deque   would nt make sense insert empty shape deque  since would waste space   far  pattern matching mouseup   pointmode   gt  begin match paintpreview   points    ps     gt  paintpreview  lt   none      gt    end think satisfies first bullet point  nt understand second one trying ask us
#
#
# hi  m working task 6  trying color sliders  first instinct accomplish task sliders affect color  ie paintcolorr  lt      however would make type mutable gctx  would nt work bc gctx supposed immutable  next idea make widget value controller holds number 0255 depending location mouse  would create mutable type paintml form type color could update   ideally  could apply mutable color type paintcolor would well good  however  concerns would like run past someone change bunch code  1 right assuming ca nt make color type mutable  tried change said incompatible cmi nt know  2 issue use record within paintml try apply paintcolor  m sure work  since one mutable type defined within gctx nt think even applicable  3 necessary create entirely new mutable state paint coexists color  seem efficient  sure else look color mutability  basically ve played around far lead errors ca nt make office hours  think main confusion rests allowed mutable  want make sure understanding conceptually change bunch code
#
#
# able pass half tests checkbox  unable pass ones click  click click click  add change listener  ve staring code ca nt seem figure s going wrong  basically created new kind widget called boxwidget hpair label widget within checkbox widget event handling occurs within boxwidget  let boxwidget  x  bool valuecontroller   widget   repaint   fun  g  gctxgctx    gt  xgetvalue   gctxdrawrect g  00   2525  else gctxfillrect g  00   2525    handle   fun  g  gctxgctx   e  gctxevent    gt  begin match e   gctxmousedown      gt  xchangevalue   xgetvalue         gt    end   size  fun    gt   2525   let checkbox  init  bool    string   widget  bool valuecontroller  let m  makecontrol init let  w  l   label let b  boxwidget  m  hpair w b  m
#
#
# m changing private specific implementation   figured tests nt passing widgettestml uses click55 event  mousedown event located  55   however  implementation checkbox hlist label  space  custom widget essentially rectangle either x drawn depending state value controller  put actual changing value controller handle function custom widget  toggling checkbox happens user actually clicks actual box  label spacer    tests nt pass  55  point falls within label  nothing triggers  nt desired behavior
#
#
#   runtest  makecontrol getvalue returns correct value set   fun     gt  let vc  makecontrol 1 let init  vcgetvalue   vcchangevalue 2  init  1  amp   amp  vcgetvalue    2  bit confused test case works  relation asm   init  vcgetvalue    would nt point vcgetvalue   vcchangevalue 2 thus resulting init  2  stay init  1   guess init set 1 init  vcgetvalue   right side substituted 1
#
#
# hello  m trouble figuring paint window gets drawn way end task 1  s understanding vlist stack elements list top  call vlist  w1  w2  w3  would draw  bottom top  w1 w2 w3  however  got opposite  ie   bottom top  w3 w2 w1  fix visually reversing order list input paintwidget  m sure whether s actually fix whether s bigger problem vlist  listlayout  etc  indication might gone wrong
#
#
# let makecontrol  v      valuecontroller  let value   contents  v  let listeners   contents      addchangelistener   fun  cl     gt  unit    gt  listeners    cl    listeners    getvalue   fun     gt   value   changevalue   fun  cv      gt  value   cv  let rec f  lst      gt  unit  list   unit  begin match lst      gt     x   xs   gt  x cv  f xs end f  listeners   hello  wrote bit code passes tests  however  wanted sure understood going  would appropriate understand references sort mutable local variable java  essentially  whenever make value controller update changing adding listeners  value controller continue value reference listeners reference store data  would mutating references store different information  bit unsure making value listeners sort  local  think would make sense make part record  inherent  controller
#
#
# ve lot trouble checkbox  thick lines activated soon start drawing line ellipse  re drag mode  everything changes thickness including border different widgets  idea given basically followed exact implementation used color  ie  adding thickness state paint thickness parameter params  withthickness fxn gctx assigns line thickness etc  second issue  checkbox toggles x goes away comes back  wo nt change state paint reason  ca nt get adjust whether lines thick thin  perform perfectly lightbulb however  must paint issue
#
#
# line preview functionality repaint function  m trying amend draw line preview last step  nt know draw shape pattern matching paintpreview  let repaint  g  gctx   unit  let drawshape   shape   unit  begin match  line  c  p1  p2    gt  drawline  withparams g c  p1 p2 end dequeiterate drawshape paintshapes   draw shape preview last  begin match paintpreview  none  gt    some  line                   gt  drawshape paintpreview end m keep getting error second last line function expecting type shape  return shape  something else wrong way ve amended function
#
#
# following code checkbox widget  let checkbox  init  bool    string   widget  bool valuecontroller  let newcontrol   valuecontroller  makecontrol init  repaint   fun  g  gctxgctx    gt  gctxdrawrect g  00   44   newcontrolgetvalue   gctxdrawstring g  00   s  x   else gctxdrawstring g  00   s      handle   fun  g  gctxgctx   e  gctxevent    gt   fst e  gctxmousedown  newcontrolchangevalue   newcontrolgetvalue       size   fun     gt  gctxtextsize    newcontrol run lightbulb  get two black boxes labels right  click corresponding label  box changes color  however  drawing rectangle  x  irrelevant lightbulb  draw  x  implementation within paint  case  repaint widgetcheckbox
#
#
# case  think logic refreshing value valid  let makecontrol  v      valuecontroller  let value   ref   contents  v  let valuecontrol      gt  unit  list ref   contents      addchangelistener   fun   gt  valuecontrolcontents  lt    valuecontrolcontents   getvalue   fun     gt  v   changevalue   fun x   gt  value   x  let rec controlloop  unit  begin match valuecontrolcontents      gt     first  rest   gt  first valuecontents end controlloop
#
#
# yes  understand function re speaking drawpoint implemented earlier types nt match  example drawpoints  p list  listiter f p f function draws one point  function drawpoint substitute drawpoint f  listiter drawpoint g p  produces type error drawpoint takes point  point list  something like let f   fun   nt know goes     gt  unit    m sure set f drawpoint s missing point parameter  ve reviewed lecture notes partial applications m still lost
#
#
# let checkbox  init  bool    string   widget  bool valuecontroller  let  w  lc   label let  w   nc   notifier w let boolcontroller  makecontrol init ncaddeventlistener  mouseclicklistener  fun     gt  boolcontrollerchangevalue   boolcontrollergetvalue        let cross  g  gctxgctx   unit  boolcontrollergetvalue   gctxdrawline g  0  0   1  1   gctxdrawline g  0  1   10  let  toggle     canvas  100  100  cross border  hpair toggle  hpair  space  10  10   w     boolcontroller hello  implemented checkbox  passed testslightbulb m part making toggle  first question  noticed buttons  lables  notifiers  etc  nt actually pass g value paint widget  part program pass g actually draw thing  confused instance  hpair  know initial graphics context  second question  would efficient way toggle  fact  nt even think correct nt think constantly checking value boolean controller  event loop running  sorry confusing questions
#
#
# getting following message try run widgettestml  seeing would problem though   anything nt fine types unit   gt  unitvaluecontroller w rm rf gml cp gnativemlx gml ocamlbuild useocamlfind pkg jsofocaml pkg jsofocamllwt pkg jsofocamllwtgraphics widgettes tnative  ocamlfind ocamlopt c package jsofocamllwtgraphics package jsofocamllwt package jsofocaml o widgetcmx widgetml file  widgetml   line 1  error  implementation widgetml match interface widgetcmi  values match  val makecontrol  unit   gt  unit valuecontroller included val makecontrol     gt   valuecontroller file  widgetml   line 234  characters 416  actual declaration command exited code 2  compilation unsuccessful building 18 targets  17 cached  000000 make    widgettestnative  error 10
#
#
# let checkbox  init  bool    string   widget  bool valuecontroller  let  w  lc   label let boolcontroller  makecontrol init let toggle  widget   repaint   gt  fun  g  gctxgctx    gt  gctxdrawrect g  0  0   snd wsize  snd wsize  handle   gt  fun     gt    size   gt   snd wsize  snd wsize   let  toggle   nc   notifier hpair toggle w ncaddeventlistener  mouseclicklistener  fun     gt  boolcontrollerchangevalue   boolcontrollergetvalue        boolcontrolleraddchangelistener  fun  b  boolean    gt  b need help  toggle   boolcontroller hello  ve struggling checkbox questions  chose method making separate widget box adding notifier hpaired box  label wherever click within widget  registers event changes value boolean controller  chose implement actual crossing adding changelistener boolean controller  feedback got ta  however   may also want consider differences changelisteners eventlisteners  neither better worse  may simplify code choose one approach registering events   see way use eventlisteners  nt see approach entire problem using changelisteners nt see way register click entire widget eventlisteners  could get help  also  wondering implement changelistener  want change box nt see way access graphics context box  let know anything guys help
#
#
# hi  keep getting error related implementation make control  error  implementation widgetml match interface widgetcmi  values match  val makecontrol  unit   gt  unit valuecontroller included val makecontrol     gt   valuecontroller file  widgetml   line 237  characters 416  actual declaration know source error could change header function  let makecontrol  v      valuecontroller  let l   contents     let x   contents  v   addchangelistener   fun y   gt  lcontents  lt   y    lcontents    getvalue   fun     gt  xcontents   changevalue   fun y       gt  xcontents  lt   y  listiter  fun x   gt  x v  lcontents
#
#
#  confused following comments guess  followup comment question    todo  need modify repaint function tasks 2  3  4      possibly 6  example  user performing operation     provides  preview   see task 2  repaint function must also     show preview    let repaint  g  gctx   unit  let drawshape   shape   unit  begin match  line  c  th  p1  p2    gt  drawline  withparams g c  p1 p2  points  c  th  ps    gt  drawpoints  withparams g c  ps  ellipse  c  th  p1  p2    gt  drawellipsefrombox  withparams g c  p1 p2 end add th thickness added field task 5  nt mention comments  however  function modified task 5  paintaction similar case says task 5   ignore adhering closely comments
#
#
# gotcha  nt current state s thickness controlled paintthickness    thick lines checkbox   let  wthickcheck  vcthickcheck   checkbox false  line thickness  let wthick  widget  border wthickcheck   vcthickcheckaddchangelistener  fun  b  bool    gt  b paintthickness  lt   thick else paintthickness  lt   thin  essentially implemented like  color button changes paintcolor  would change specific graphic context s current thickness   pass one argument change listener
#
#
# paint application nt displayed properly keep seeing vpair function messing everything ca nt figure mine nt work  ve spent day one part  help much appreciated  code  let vpair  w1  widget   w2  widget   widget   repaint   fun  g  gctxgctx    gt  w1repaint g  let g  gctxtranslate g  snd  0   w1size      w2repaint g   handle   fun  g  gctxgctx   e  gctxevent    gt  eventwithin g e  w1size    w1handle g e else let g   gctxtranslate g  snd  0   w1size       eventwithin g e  w2size    w2handle g e else     size   fun     gt  let  x1  y1   w1size   let  x2  y2   w2size    max x1 x2  y1  y2
#
#
# ca nt get lightbulb text display  check box toggle works  text display know  let checkbox  init  bool    string   widget  bool valuecontroller  let value  makecontrol init let r   contents   let par   contents  init    repaint   fun  g  gctxgctx    gt  gctxdrawrect g  010   10  10    valuegetvalue     gctxdrawline g  00   10  10   gctxdrawline g  100   010    else     handle   fun  g  gctxgctx   e  gctxevent    gt  begin match  gctxeventtype e   gctxmousedown   gt  valuechangevalue   valuegetvalue         gt    end   size   fun     gt  let  x1  y1   gctxtextsize rcontents  x111  max y1 11       value
#
#
# ve read instructions task 4  looked piazza posts m still confused  mainly  re asked implement ellipse using bounding box method modify original parameters drawellipse   defined  us  gctxml   1444 stated need adjust parameters according bounding box method passing drawellipse  actually mean  see  relevant mode constructors would start point end point  passing drawellipse   parameters interested different parameters takes
#
#
# paintml  trying update fields paintcolor  trying calling addchangelistener slider s state  example red slider state  passing function takes type int returns type unit  function  trying modify paintcolor updating field interest  case  red field  int value passed  example  m passing n  original fields paintcolor  cr  cg  cb   want update fields  w  cg  cb   issue m running access fields paintcolor use original value updating final values
#
#
# hi 2 bugs past hours could figure occurring 1my slider working reverse moves right thought made value would increase decreasing understand 2  use line thickness derived slide value checkbox thickness however seem working quite right line thickness value resets still modified slidereven though nested conditions slide counter value would used thickness checkbox understand happening  someone could help one would really appreciate
#
#
# never decided use  w  h2  check bounds  fact  widget shows behavior even nt check eventpos within widget  think may something way drawrect works  drawrect takes position  width  height  position ends bottom left corner  given clicking one full height bottom edge rectangle leads changing state slider  m guessing disconnect object drawn object interpreting space
#
#
# nt know keeps saying  unbound value size  meanwhile saying  undefined record fields size   let slider  init  int   widget  int valuecontroller  let slcontroller  makecontrol init let w    repaint   fun  g  gctxgctx    gt  gctxdrawrect g  010   2560   gctxfillrect g  09   slcontrollergetvalue   1    handle   fun  g  gctxgctx   e  gctxevent   unit   gt   begin match gctxeventtype e  mousedrag   gt  let p  fst  gctxeventpos e g  slcontroller  changevalue p  mousedown   gt  let p  fst  gctxeventpos e g  slcontroller  changevalue p     gt    end   size   fun     gt   25610      w   slcontroller
#
#
# hello  ve looked piazza posts even actually asked private post still ca nt fix issue  although think identified   think reason thickness toggle also making borders thick change thickness entire paintthickness thick repaint  borders come thick  stuck fix issue  namely  change thickness things drawn canvas widgets   weird reason borders drawn way probably drawn paintm   ve command  f ed places color goes made sure thickness behaves  also add new shapes deque current thickness draw correct thickness  ve stuck quite  would possible receive bit help identify making mistake  would help tremendously someone could look code   sorry s bit much asking
#
#
# see line button point button  point function work  could wrong  paint action  mouse  begin match paintmode  pointmode   gt  let  ps  point list   p     paintpreview  lt    points  paintcolor  ps       gt    end  mousedrag   gt    case  mouse clicked  s dragged     button  initially nothing  ll     need update part task 2  3  4 maybe 6    begin match paintmode  linestartmode   gt  paintmode  lt   lineendmode p  lineendmode p1   gt  paintpreview  lt    line  paintcolor  p1  p    pointmode   gt  let points  begin match paintpreview   points    ps     gt  ps     gt    end paintpreview  lt    points  paintcolor  points   end  mouseup   gt    case mouse button release event  todo  tasks 2      3  4  possibly 6 need something different    begin match paintmode  linestartmode   gt     lineendmode p1   gt  paintpreview  lt   none  dequeinserttail  line  paintcolor  p1  p   paintshapes  paintmode  lt   linestartmode  pointmode   gt  paintpreview  lt   none  let points  begin match paintpreview   points    ps     gt  ps     gt    end points     dequeinserttail  points  paintcolor  points   paintshapes  paintmode  lt   linestartmode end
#
#
# hello  following code implementation part task 5  let checkbox  init  bool    string   widget  bool valuecontroller  let  w     label let  w2  nc   notifier w let vc  makecontrol init let statechange   fun     gt  vcchangevalue   vcgetvalue      ncaddeventlistener  mouseclicklistener statechange    w  vc  know still need modify repaint  right struggling understanding change value truefalse mouse clicks  thought next last line achieving  passing click click click click tests  recognize value nt changing like  think part problem trying understand differences code handle  widget   notifier controller s list event listeners  value controller s list  thanks
#
#
# file  gctxml   line 218  characters 78  error  syntax error command exited code 2  hint  recursive traversal subdirectories enabled build  working directory look like ocamlbuild project  tags  myocamlbuildml  file   modules subdirectories  add option  r  create empty tags  file  enable recursive traversal subdirectories  use following tags  file  true  traverse  lt  dir1  gt   lt  dir2  gt   traverse compilation unsuccessful building 9 targets  8 cached  000000 make    gdemobyte  error 10 codio  peppersimple  workspace  getting following error drawpoints function gctxml happens ocaml tries build whole project  otherwise ocaml nt give errors  could error coming  thanks
#
#
# two things wrong codio  it longer showing debugging errors  like red dots next lines   ve closed  refreshed  etc  ca nt debug  i keep getting error even though code seems make perfect sense  m q5  makecontrol   hint  recursive traversal subdirectories enabled build  working directory look like ocamlbuild project  tags  myocamlbuildml  file   modules subdirectories  add option  r  create empty tags  file  enable recursive traversal subdirectories  use following tags  file  true  traverse  lt  dir1  gt   lt  dir2  gt   traverse  help please
#
#
# look  ca nt come office hours need help function least move spend next 8 hours staring  let makecontrol  v      valuecontroller  let value   ref  ref v let changelistenerlist      gt  unit  list ref  ref    addchangelistener  fun  newl     gt  unit    gt   cons new function onto list  changelistenerlistcontents  lt   newl   changelistenerlistcontents  getvalue   fun     gt  valuecontents    just return v    changevalue   fun  v      gt  valuecontents  lt   v  let rec iterate  myval     func      gt  unit  list   unit  begin match func      gt     head  tail   gt  head myval  iterate myval tail end iterate valuecontents changelistenerlistcontents   issues  1  getvalue changevalue coming unbound nt understand two also addchangelistener 2  changevalue giving  bool instead unit  error apparently happens nt parenthesis  added parenthesis whole anonymous function nothing happened  ocaml stupid  mean goes without question  logic error something function
#
#
# m trying make sliders filled colors red green blue   s filling black  m using withcolor function though  ca nt figure m wrong  let slider  init  int   c  gctxcolor   widget  int valuecontroller  let sliderhelper  makecontrol init let width  200 let height  20 let w   repaint   fun  g  gctxgctx    gt  gctxfillrect  gctxwithcolor g c   0  20   sliderhelpergetvalue    height   gctxdrawrect g  sliderhelpergetvalue    20   width  sliderhelpergetvalue    height    handle   fun  g  gctxgctx   e  gctxevent    gt  begin match gctxeventtype e  gctxmousedown   gt  sliderhelperchangevalue  fst  gctxeventpos e g    gctxmousedrag   gt  sliderhelperchangevalue  fst  gctxeventpos e g       gt    end   size   fun     gt   width  height      w  sliderhelper
#
#
# trying implement red color slider  running 2 major issues  1  slider sets value r 0 instantly wherever click 2  color changed drag text  red slider   actual slider  code  help would greatly appreciated  widgetml  let colorslider  init  int    string   widget  int valuecontroller  let  makecontrol init let w   repaint   fun  f  gctxgctx    gt  gctxdrawstring f  0  0    handle   fun  f  gctxgctx   g  gctxevent    gt  let  x  y   gctxeventpos g f  gctxeventtype g  gctxmousedown achangevalue  min x 50   gctxeventtype g  gctxmousedrag achangevalue  min x 50   gctxeventtype g  gctxmouseup achangevalue  min x 50     size   fun     gt  gctxtextsize    w   paintml  let wslider  widget  let  switchw  switchcb   widgetcolorslider 0  red slider  let  switchcbgetvalue   switchcbaddchangelistener  fun x   gt  paintcolor  lt    r  50  x  g  paintcolorg  b  paintcolorb    let thickbulb  g  gctx   unit   let gnew  withcolor g gctxred in  drawrect g  0  10   150  10   gctxfillrect g  0  10    5  let  bulb     widgetcanvas  015  thickbulb widgethpair switchw bulb
#
#
# let checkbox  init  bool    string   widget  bool valuecontroller  let  widg  lbl   label let  widg2  notify   notifier widg  widg2  makecontrol init  tried multiple implementations checkbox  none worked  baseline implementation based button function  create widget label notifier top   quite confused widget functions go  look like versus   thought implemented outside widget file  however test cases say otherwise
#
#
# currently attempting get slider slide  seem trouble  slider consists widget int value controller  issue somewhere handle  slider widget  let slider  init  int    string   widget  int valuecontroller  let scontrol  makecontrol init let  x  y   gctxtextsize   repaint   fun  g  gctxgctx    gt  gctxdrawstring g  00   gctxdrawrect g  x  y   10020   gctxdrawline g  xscontrolgetvalue    y   xscontrolgetvalue    y20    handle   fun  g  gctxgctx   e  gctxevent    gt  let helper  ev  gctxevent   unit  begin match ev  mousedown     gt  let      snd e  ax  gt  0   amp   amp   ax  lt  100  scontrolchangevalue    mousedrag     gt  let      snd e  ax  gt  0   amp   amp   ax  lt  100  scontrolchangevalue       gt    end helper e   size   fun     gt   x100  y      scontrol  suggestions slider might updating line drawing method
#
#
# responding  tried changing x y values previous nt factor value controller input  slider update value controller given range coordinates  size rectangle  line redrawn new x value mouses position dragged clicked  listeners updated  gotten yet   value controller updating properly  updated properly checkbox  m using widget value controller set create slider  apologies giving little context  thoughts  think problem somewhere handle ca nt figure
#
#
# hi  m struggling get logics straight handle event slider  got far  let colorslider  init  int    string   widget  int valuecontroller  let  lw  lc   label let vc  makecontrol init let slider   repaint   fun  g  gctxgctx    gt  gctxdrawrect g  0  10   256  10   gctxfillrect g  0  10   vcgetvalue    10    handle   fun  g  gctxgctx   e  gctxevent    gt  begin match e   enable clickdrag     gctxmousedown   p1  p2     gt       gctxmousedrag   p1  p2     gt  vcchangevalue  p1     gctxmouseup   p1  p2     gt    new value set   vcchangevalue  p1       gt    end   size   fun     gt   256  10     let  wslider  ncslider   notifier  hlist  lw  border  slider      todo  ncslideraddeventlistener  mouseclicklistener  fun     gt        wslider  vc  know need work addeventlistener part  nt quite get logic different mouse events  update value dragged   s difference drag mouseup  much
#
#
# getting  make  nothing done    building paint ever since implementing slider function  looked everything really ca nt find s wrong slider function  added widget slider  update widgetmli   let sliderlistener  cp  int valuecontroller   eventlistener  fun  g  gctxgctx   e  gctxevent    gt  let x    gctxeventpos e g begin match gctxeventtype e gctxmousedrag   gt  cpchangevalue x    gt    end let slider  init  int   w  int   c  gctxcolor   widget  int valuecontroller  let vc  makecontrol init let sliderbuilder  init  int   width  int   c  gctxcolor   widget  notifiercontroller  let repaintslider  gc  gctxgctx   gctxfillrect  gctxwithcolor gc c   0  9   init  1  9   canvas  width9  repaintslider let slider  nc  sliderbuilder  vcgetvalue    w c ncaddeventlistener  sliderlistener vc   let bordered  border slider bordered  vc added paint  let wrslider  vcrslider  slider 0 255 red   vcrslideraddchangelistener  fun v   gt  paintcolor  lt    r  v  g  paintcolorg  b  paintcolorb   let wgslider  vcgslider  slider 0 255 green   vcgslideraddchangelistener  fun v   gt  paintcolor  lt    r  paintcolorr  g  v  b  paintcolorb   let wbslider  vcbslider  slider 0 255 blue   vcbslideraddchangelistener  fun v   gt  paintcolor  lt    r  paintcolorr  g  paintcolorg  b  v    let rgbtoolbar  widget  vlist  wrslider  spacer  wgslider  spacer  wbslider   let paintwidget  vlist  paintcanvas  spacer  modetoolbar  spacer  rgbtoolbar  spacer  colortoolbar
#
#
# let checkbox  init  bool    string   widget  bool valuecontroller  let  widg  lbl   label let  widg2  notify   notifier widg let  widgx  onlbl   label  x  let  widgblank  offlbl   label   let rtncontr  makecontrol init   add toggle function   let rtncontraddchangelistener  lt    fun     gt   getvalue     add different visual states versus   let w  widg2repaint  lt    rtncontrgetvalue hpair  widgx  space  lbl  else hpair  widgblank  space  lbl    w  rtncontr  nt understand add function addchangelistener field instance record  compiler nt understand trying  thanks
#
#
# let checkbox  init  bool    string   widget  bool valuecontroller  let rtncontr  makecontrol init let  widg2  lbl   label let  widg3  notify   notifier widg2 let  widgx  onlbl   label  x  let  widgblank  offlbl   label   let widg   repaint   fun  g  gctxgctx    gt  rtncontrgetvalue   drawboxinoneway    hlist  widgx  space  widg3        else drawboxanotherway    hlist  widgblank  space  widg3          handle   fun     gt      size   fun    gt  dim    widg  rtncontr  working code  gotten far nt really know proceed  tips help greatly appreciated spent hours trying figure parts funciton  understand  basic structurewhat needs done widget  1  make widget  2  add repaint function getvalue  else  3  add label  4  add notifier  5  create makecontrol init  6  addchangelistener fun     gt   getvalue   ie  toggle  nt know understanding syntax  completely misunderstanding portions  checkbox  method checkbox function doinghowwhere
#
#
# case  widget  repaint  handle  size   widget needs way repaint  vary depending whether  way handle events  clicked  click changing state   however gctx specify draw widgets paint handle events  button canvas widgets nt really deal either aspects  return widgetlabelcontrollernotifiercontroller widget  notifiercontroller respectively   therefore paint gctx deal drawinghandling widget  since checkbox takes string  add label  nt functionality draw  return notifiercontroller event handling  make checkbox widget draw handle event  addition  label nt take widget  call label string given  get new widget  change values repainthandle widget  likewise  get labelcontroller notifiercontroller  nt return either  values   also response  helpful
#
#
# really struggling function  specifically trouble understanding step step process need follow order implement  know need keep track whether box checked  depend state passed  nt know means  false  passed versus  true   making difficult know set state function  wrote pseudocode widget m sure size  sure repaint  actually need draw checkbox function    repaint  gctxgctx   gt  unit   if state checkbox checked  then paint checkbox according graphics context   handle   gctxgctx   gt  gctxevent   gt  unit   if mouse click event detected within box  change state checkbox  checked     size  unit   gt  gctxdimension   do nt know here   reading description problem posts  think questions make clear understand little function help get meaningfully started appreciated
#
#
#   create thick lines checkbox   let  wthick  crtlthick   checkbox false  thick lines    funciton runs thick lines checkbox pressed   let thicklines    unit  crtlthickaddchangelistener  fun b   gt  b paintthickness  lt   thick else paintthickness  lt   thin  implemented thickness throughout paintgtcxmlgtxcmli believe work   thick line  button appears window  press  x  appears  however change thickness line  assume problem stems code  however nt know making mistake
#
#
# working implementing color sliders  really struggling  read many piazza posts  ca nt seem figure implementation failing work  implementing red slider start  ca nt get bar move  sure source error  program recognizing change value  mouse positioning  checked things ca nt seem figure issue  nt think issue m drawing manually code value  bar changes supposed
#
#
# checkbox part task 5  trying make bool valuecontroller tried passing statuscontents makecontrol end get error unbound record field status  let checkbox  init  bool    string   widget  bool valuecontroller  let r   contents   let status   contents  init   repaint   fun  g  gctxgctx    gt   status  gctxdrawline  gctxwithcolor g gctxblack   0  1   9  10   gctxdrawline  gctxwithcolor g gctxblack   0  10   9  1   else    gctxdrawstring g  11  0  rcontents   handle   fun  g  gctxgctx   e  gctxevent    gt  gctxeventtype e  gctxmousedown statuscontents  lt    statuscontents  else     size   fun     gt  let  x1  y1    gctxtextsize rcontents  let  x2  y2    11  11    x1  x2   max y1 y2      makecontrol statuscontents
#
#
# let slider  init  int   c  gctxcolor   widget  int valuecontroller  let valcontroller  makecontrol init  repaint   fun  g  gctxgctx    gt  gctxdrawrect g  0  10   100  10   gctxfillrect  gctxwithcolor g c   0  10   valcontrollergetvalue    10    handle   fun  g  gctxgctx   e  gctxevent    gt  let  x     gctxeventpos e g begin match gctxeventtype e  gctxmousedown   gt  valcontrollerchangevalue  x   gctxmousedrag   gt  valcontrollerchangevalue  x   gctxmouseup   gt  valcontrollerchangevalue  x      gt    end   size  fun     gt   100  10    valcontroller hello  slider widget  patternmatched mouesdown  mousedrag  mouse honestly nt feel like things differently   work   however  case  would get points style  fundamentally  things diffrently drag  mousedown  mouse
#
#
# error showed switched black fillrect red  green  blue filled rectangles sliders  lines around rectangles turned seemingly random colors  bug coming sudden  code slider  let slider  pos  int   c  gctxcolor   widget  int valuecontroller  let newcontrol  int valuecontroller  makecontrol pos let width  height   255  10   repaint   fun  g  gctxgctx    gt  gctxdrawrect g  0  10   width  height   gctxfillrect  gctxwithcolor g c   0  10   newcontrolgetvalue    height    handle   fun  g  gctxgctx   e  gctxevent    gt   fst e  gctxmousedown  fst e  gctxmousedrag    fst  gctxeventpos e g   lt  0  newcontrolchangevalue 0 else  fst  gctxeventpos e g   gt  255  newcontrolchangevalue 255 else newcontrolchangevalue  fst  gctxeventpos e g      size   fun     gt   width  height     newcontrol code paintml  let  rslidew  rslidevc   slider 0  red  let mklistenerrslide   int   unit  paintcolor  lt    r   g  paintcolorg  b  paintcolorb    rslidevcaddchangelistener  mklistenerrslide  let  gslidew  gslidevc   slider 0  green  let mklistenergslide   int   unit  paintcolor  lt    r  paintcolorr  g   b  paintcolorb    gslidevcaddchangelistener  mklistenergslide  let  bslidew  bslidevc   slider 0  blue  let mklistenerbslide   int   unit  paintcolor  lt    r  paintcolorr  g  paintcolorg  b     bslidevcaddchangelistener  mklistenerbslide
#
#
# rgb sliders functional  changing rgb values pen  repainting  code structured way checkbox code m sure  error overlooking code  let sliderlistener  cp  int valuecontroller   eventlistener  fun  g  gctxgctx   e  gctxevent    gt  let x    gctxeventpos e g begin match gctxeventtype e gctxmousedrag   gt  cpchangevalue x gctxmousedown   gt  cpchangevalue x gctxmouseup   gt  cpchangevalue x    gt    end let slider  init  int   w  int   c  gctxcolor   name  string   widget  int valuecontroller  let vc  makecontrol init let sliderbuilder  init  int   width  int   c  gctxcolor   widget  notifiercontroller  let repaintslider  gc  gctxgctx   gctxfillrect  gctxwithcolor gc c   0  9   init  9   canvas  width9  repaintslider let slider  nc  sliderbuilder  vcgetvalue    w c ncaddeventlistener  sliderlistener vc   let l    label name let full  hlist  slider  space  55   l  let bordered  border full bordered  vc
#
#
# rm rf gml cp gjsmlx gml ocamlbuild useocamlfind pkg jsofocaml pkg jsofocamllwt pkg jsofocamllwtgraphics lightbulbbyte circular dependencies   eventloopcmo  already seen   paintcmo    widgetcmo    eventloopcmo   hint  recursive traversal subdirectories enabled build  working directory look like ocamlbuild project  tags  myocamlbuildml  file   modules subdirectories  add option  r  create empty tags  file  enable recursive traversal subdirectories  use following tags  file  true  traverse  lt  dir1  gt   lt  dir2  gt   traverse compilation unsuccessful building 26 targets  22 cached  000000 make    lightbulbbyte  error 9 codio  buttonpromise  workspace  messing around widgetml paintml suddenly code stopped compiling  idea cause could  nt see red lines anything like  strange
#
#
# getting compiler error line run   ocaml nt red errors side  pattern matching two positions get x y postions  could wrong  begin match p1  c  x1  y1    gt  begin match p2  d  x2  y2    gt  drawellipse  withparams g c   abs   x1  x2  2   abs   y1  y2x  2    abs  x1x2    abs  y1y2   end end
#
#
# type slidecontroller   mutable percentage  float  mutable maxi  int  let makeslidecontrol  v  int   slidecontroller   percentage  10  maxi  v  let slider  x  int   mx  int   widget  slidecontroller  let slid   percentage   floatofint  x    floatofint  mx    maxi  mx  let w   repaint   fun  g  gctxgctx    gt   gctxdrawrect g  0  0   gx  gy   gctxdrawrect g  0  0   intoffloat  slidpercentage   gx  gy     handle   fun  g  gctxgctx   evnt  gctxevent    gt  begin match evnt   gctxmousedrag      gt  let pos  eventpos gmousedrag g let  x  y   pos slidpercentage  lt   floatofint  gx    floatofint  slidmx      gt    end   size    w  slid  attempting implement slider widget shown  getting multiple syntax errors completely sure implementation work  implementation seem logical  properly access gx  gy  eventpos  mousedrag
#
#
# stuck  ca nt figure error  keeps saying  syntax error unclosed   expecting     suspect m something wrong iterating list listeners  let makecontrol  v      valuecontroller  let value  ref v let listeners  ref    addchangelistener   fun  x     gt  unit    gt  listeners   x    listeners   getvalue   fun     gt   value   changevalue   fun x   gt  value   x    listiter  fun  lis     gt  unit    gt  lis  value   listeners
#
#
# reason  even though passing black graphics context drawrect sliders function  drawing multicolored borders around red  green  blue sliders get painted  instead black borders  could reason bug   okay  code  let slider  pos  int   c  gctxcolor   widget  int valuecontroller  let newcontrol  int valuecontroller  makecontrol pos let width  height   255  10   repaint   fun  g  gctxgctx    gt  gctxdrawrect  gctxwithcolor g gctxblack   0  10   width  height   gctxfillrect  gctxwithcolor g c   0  10   newcontrolgetvalue    height    handle   fun  g  gctxgctx   e  gctxevent    gt   fst e  gctxmousedown  fst e  gctxmousedrag    fst  gctxeventpos e g   lt  0  newcontrolchangevalue 0 else  fst  gctxeventpos e g   gt  255  newcontrolchangevalue 255 else newcontrolchangevalue  fst  gctxeventpos e g      size   fun     gt   width  height     newcontrol tried add setgraphicsstate  changed nothing ran  says unbound setgraphicsstate  still showing colored borders unfortunately
#
#
# really figure wrong checkbox function  pass tests odd clicks  listener test  m sure parts wrong whether m making logic mistake  let checkbox  init  bool    string   widget  bool valuecontroller  let ssize  gctxtextsize let boxsize   snd ssize  snd ssize  let bvc  makecontrol init let state  bool ref  ref init let square   repaint   fun  g  gctxgctx    gt  init  true gctxfillrect g  00  boxsize else gctxdrawrect g  00  boxsize   handle   fun  g  gctxgctx   e  gctxevent    gt  eventwithin g e boxsize state     state    size   fun    gt  boxsize   let label  widget   repaint   fun  g  gctxgctx    gt  gctxdrawstring g  00    handle   fun     gt      size   fun    gt  ssize    hpair square label  bvc
#
#
# really nt know m going wrong  let checkbox  init  bool    string   widget  bool valuecontroller  let   b   label let  c  d   notifier let checkvalct  makecontrol init let checkwidget   repaint   checkvalctgetvalue    fun  g  gctxgctx    gt  gctxdrawstring g  00    x     else  fun  g  gctxgctx    gt  gctxdrawstring g  00     handle   fun  g  gctxgctx   e  gctxevent    gt   begin match gctxeventtype e mousedown   gt  checkvalctaddchangelistener  fun z   gt  checkvalctgetvalue    graphicssetlinewidth 5  checkvalctchangevalue false  else  graphicssetlinewidth 1  checkvalctchangevalue true     gt    end    size  csize   checkwidget  checkvalct
#
#
# struggling modifying size function checkbox since issue lightbulb  currently checkbox function reads follows colors change click within text area little cross appears disappears  still mass space supposed change light clicked think issue may hard coded size widget supposed hard code size function size lightbulb widget  sure pass size lightbulb widget  general widget  modify size function let checkbox  init  bool    string   widget  bool valuecontroller  let r   contents   let checkcontrol  makecontrol init  repaint   fun  g  gctxgctx    gt    checkcontrolgetvalue      gctxdrawline  gctxwithcolor g gctxblack   0  1   9  10   gctxdrawline  gctxwithcolor g gctxblack   0  10   9  1   else    gctxdrawstring g  11  0  rcontents   handle   fun  g  gctxgctx   e  gctxevent    gt  gctxeventtype e  gctxmousedown checkcontrolchangevalue   checkcontrolgetvalue     else     size   fun     gt  let  x1  y1    gctxtextsize rcontents  let  x2  y2    11  11    x1  x2   max y1 y2     checkcontrol
#
#
# trying implement checkbox widget inside checkbox  code wrote handle   fun g e   gt  let someaction    unit  vcchangevalue   vcgetvalue     gctxeventtype e  gctxmousedown someaction   else   vc value controller  tests passing received  graphicsgraphicfailure   graphic screen opened    error  faqrecommendss nt call anything graphics module widget module  m unsure proceed  tried alternate implementation like similar results  begin match gctxeventtype e gctxmousedown   gt  someaction      gt    end
#
#
# trying implement thickness checkbox paintml m running weird errors  goal reverse state value inside checkbox s value controller  want perform unit  gt  unit action mouse clicked  created helper function design type unit unit  bringing errors  try make input mouseclick listener keep getting error  expr type unit expecting unit   gt  unit   wrong  reference  twvc value listened thickness widget checkbox  let unittounit    unit  let k  bool   twvcgetvalue    twvcchangevalue  k  mouseclicklistener  unittounit
#
#
# hi  following code m getting error  syntax error unclosed   expecting     last else statement  ve gone office hours still ca nt seem find source  help  repaint   fun  g  gctxgctx    gt  let width  2 let height  2 gctxdrawrect g  00   width  height    draw square regardless state  gctxdrawstring g  width  1  0    draw string regardless state   does label      checkboxstategetvalue    draw check box  gctxdrawline g  00   width  height   gctxdrawline g  width0   0  height   else    do draw checkmark
#
#
# bug prevented even moving testing check box functionality  sat office hours staring 2 hours far suggestions helped  nt complete task 5 this  syntax error unclosed   expecting     last else statement repaint   fun  g  gctxgctx    gt  let width  2 let height  2 gctxdrawrect g  00   width  height    draw square regardless state  gctxdrawstring g  width  1  0    draw string regardless state  checkboxstategetvalue    draw check box  gctxdrawline g  00   width  height   gctxdrawline g  width0   0  height   else    do draw checkmark
#
#
# nt really understand checkbox would passing one click tests two  full checkbox  let checkbox  init  bool    string   widget  bool valuecontroller  let checkboxstate  makecontrol init   tuple start   repaint   fun  g  gctxgctx    gt  let width  2 let height  2 gctxdrawrect g  00   width  height    draw square regardless state  gctxdrawstring g  width  1  0    draw string regardless state   does label      checkboxstategetvalue    draw check box   gctxdrawline g  00   width  height   gctxdrawline g  width0   0  height    else    do draw checkmark    handle   fun  g  gctxgctx   e  gctxevent    gt   what use gctxgctx       let click  gctxeventtype e begin match click  gctxmouseup   gt  let trueorfalse  checkboxstategetvalue   checkboxstatechangevalue  trueorfalse     checkboxstateaddchangelistener  function         gt    end    string go label     size   fun     gt  gctxtextsize    checkboxstate   tuple end  seems like issue handle  thought method changing value would sufficient  also need call addchangelistener somewhere  add kind changelistener  nt understand s necessary even put
#
#
# nt even know start slider widget  return int controller  considering repaint  currently something like repaint   fun  g  gctxgctx    gt   draw slider line regardless state  gctxdrawline g  00   0  lineheight   gctxdrawline g  0  lineheight   linewidth  lineheight   gctxdrawline g  linewidth  lineheight   linewidth  0   gctxdrawline g  linewidth0   00    draw sliding rectangle depending state  let x  sliderstategetvalue    gctxdrawrect g  x0   sliderboxw  sliderboxh      controller supposed type int pass x values updates based user dragging mouse  earth supposed happen  handle following nt feel right  handle   fun  g  gctxgctx   e  gctxevent    gt   what use gctxgctx       let click  gctxeventtype e begin match click  gctxmousedown   gt  let x  sliderstategetvalue   sliderstatechangevalue  x    get x change x     feel like m missing step      gt    end
#
#
# think storing x position mouse cursor value controller  currently following handle nt know valid way  furthermore line let xpos  fst pos gives error pos underlined  expression gctxgctx   gt  position expression type    b expected  handle   fun  g  gctxgctx   e  gctxevent    gt   what use gctxgctx       let click  gctxeventtype e let pos  gctxeventpos e let xpos  fst pos begin match click  how get mouse coordinate add int value controller     gctxmousedown   gt   sliderstatechangevalue  xpos     gctxmousedrag   gt   sliderstatechangevalue  xpos        gt    end   storing mouse x coords account dynamic updating re trying drag slider
#
#
# AVERAGE 25.055005500550056
# MaxLength 188
# Length 909
# Length 909

# %%
from bert_serving.client import BertClient  
bc = BertClient(check_version=False)  
doc_vecs = bc.encode(raw_questions_to_hw["hw5"])
# Out:
# /Users/maralevy/miniconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py:286: UserWarning: some of your sentences have more tokens than "max_seq_len=50" set on the server, as consequence you may get less-accurate or truncated embeddings.
# here is what you can do:
# - disable the length-check by create a new "BertClient(check_length=False)" when you do not want to display this warning
# - or, start a new server with a larger "max_seq_len"

# %%
# This cell allows you to type a question and find semantically similar questions using BURT, eventually
# we should run this for every question in raw_questions

import np
print(doc_vecs)
topk = 5
for question in raw_questions_to_hw["hw5"]:
    query_vec = bc.encode([question])
    # query_vec = bc.encode([query])
    # compute simple dot product as score
    score = np.sum(query_vec * doc_vecs, axis=1)/np.linalg.norm(doc_vecs, axis=1)
    topk_idx = np.argsort(score)[::-1][:topk]
    print("Question: ")
    print(question)
    for idx in topk_idx:
        print('> %s\t%s' % (score[idx], raw_questions_to_hw["hw5"][idx]))
# Out:
# [[-0.52952826 -0.36128572  0.6193738  ... -0.45791903 -0.5624408
#    0.7073593 ]
#  [ 0.03624303 -0.07752288 -0.13927698 ... -0.09961917 -0.22631712
#    0.12387063]
#  [-0.61032844 -0.01437361  0.8244882  ... -0.49853957  0.09914736
#    0.48431036]
#  ...
#  [-0.49188447 -0.05632136  0.7954209  ... -0.7545638  -0.26255596
#    0.36835623]
#  [-0.5745432  -0.03924503  0.56918293 ... -0.5853857  -0.37736058
#    0.34111038]
#  [-0.89465934 -0.2868816   0.72648144 ... -0.43443713 -0.05486085
#    0.16292454]]
# Question:
# code wont compile removed kudos problem dequeml becuase error without touching many points lose code compiling
# > 17.766563	my code wont compile because I removed the kudos problem on deque.ml becuase it had an error without me touching it; how many points will we lose for our code not compiling
#
# > 16.996243	I'm getting an unbound value for a function called with_thickness that I created. After building and cleaning the project, I have no other compilation errors in any other files. What could be wrong?
# > 16.976013	This bug prevented me from even moving on to testing the check box functionality. I sat in office hours staring at this for 2 hours and so far no suggestions have helped. I didn't complete Task 5 because of this.
#
#  " Syntax error after unclosed (, expecting ')' " on the very last else statement
#
# repaint =
#   (
#   fun (g: Gctx.gctx) -&gt;
#         let width = 2 in
#         let height = 2 in
#         Gctx.draw_rect g (0,0) (width,height); (*draw the square regardless of state*)
#         Gctx.draw_string g (width + 1, 0) s;   (*draw the string regardless of state*)
#         if checkbox_state.get_value()
#         then (*draw check on box*)
#         Gctx.draw_line g (0,0) (width,height);
#         Gctx.draw_line g (width,0) (0,height);
#         else () (*do not draw checkmark*)
#    );
#
#
#
# > 16.975187	When I clean and build my code I get unbound errors all over on things that were not underlined before or modified. For example,  Deque.iterate, shapes, and mode to name a few. This happened once before - I let codio go for a while and it fixed itself, however, after I tried cleaning and building again, the errors reappeared. This time, I've tried refreshing the page several times and restarting codio but the errors stay. Is there anything that I'm doing wrong? Thank you
# > 16.921856	I was working on my code, and all of the sudden I started getting this error "Unbound type constructor widget" for hpair and button as well. I undid all of the changes I made, but this is still showing up. I don't know why.
#
# After a few more moments, it's now started happening for all of the types defined in Gctx as well
# Question:
# paint released
# > 14.1827965	When will PAINT be released?
# > 12.247088	My paint pop up is blank after running it. Any reason why?
# > 12.097597	Is it OK for our slider to only work with floats?
# > 12.059295	Why does my paint GUI look like this?
#
# > 11.998533	I think I covered all of the cases
#
# Question:
# implement rectangle ellipse run gdemo  red square red circle instead red square blue circle  concerning
# > 16.696983	After I implement rectangle and ellipse and run gdemo, I have a red square and red circle instead of a red square and a blue circle. Should this be concerning?
# > 15.617478	In task 0 my ellipse and rectangle are in the correct location, however, the color of my ellipse is red when it should be blue.
# > 15.467222	For some reason, even though I am passing in a black graphics context to draw_rect in my sliders function, it is drawing multicolored borders around where the red, green, and blue sliders get painted, instead of black borders. What could be the reason for this bug? Or, is this okay?
#
# Here is my code:
#
# let slider (pos: int) (c: Gctx.color) : widget * int value_controller =
#   let new_control : int value_controller = make_control pos in
#   let width, height = (255, 10) in
#   { repaint = (fun (g: Gctx.gctx) -&gt;
#         Gctx.draw_rect (Gctx.with_color g Gctx.black) (0, 10) (width, height);
#         Gctx.fill_rect (Gctx.with_color g c) (0, 10) (new_control.get_value(), height));
#     handle = (fun (g: Gctx.gctx) (e: Gctx.event) -&gt;
#     if (fst e == Gctx.MouseDown || fst e == Gctx.MouseDrag)
#     then (if (fst (Gctx.event_pos e g) &lt; 0) then new_control.change_value 0
#           else if (fst (Gctx.event_pos e g) &gt; 255) then new_control.change_value 255
#           else new_control.change_value (fst (Gctx.event_pos e g))));
#     size = (fun () -&gt; (width, height))}, new_control
#
# When I tried to add set_graphics_state, it changed nothing when I ran it, and now it says unbound set_graphics_state.
#
# It is still showing colored borders unfortunately.
# > 15.410995	I have implemented a drawing ellipses function but my ellipse expands from the center instead of using the bounding box method (even though that's what I tried to do). How can I fix this?
# > 15.410277
# I have an error that showed up when I switched from a black fill_rect to red, green, and blue filled rectangles for my sliders. The lines around each of the rectangles have turned seemingly random colors.  Where is this bug coming from all of a sudden?
# Here is my code for slider:
# let slider (pos: int) (c: Gctx.color) : widget * int value_controller =
#   let new_control : int value_controller = make_control pos in
#   let width, height = (255, 10) in
#   { repaint = (fun (g: Gctx.gctx) -&gt;
#         Gctx.draw_rect g (0, 10) (width, height);
#         Gctx.fill_rect (Gctx.with_color g c) (0, 10) (new_control.get_value(), height));
#     handle = (fun (g: Gctx.gctx) (e: Gctx.event) -&gt;
#     if (fst e == Gctx.MouseDown || fst e == Gctx.MouseDrag)
#     then (if (fst (Gctx.event_pos e g) &lt; 0) then new_control.change_value 0
#           else if (fst (Gctx.event_pos e g) &gt; 255) then new_control.change_value 255
#           else new_control.change_value (fst (Gctx.event_pos e g))));
#     size = (fun () -&gt; (width, height))}, new_control
# And here is my code in paint.ml:
# let (rslide_w, rslide_vc) = slider 0 (red)
#
# let mk_listener_rslide (i: int) : unit =
#   paint.color &lt;- {r = i; g = paint.color.g; b = paint.color.b}
#
# ;; rslide_vc.add_change_listener (mk_listener_rslide)
#
# let (gslide_w, gslide_vc) = slider 0 (green)
#
# let mk_listener_gslide (i: int) : unit =
#   paint.color &lt;- {r = paint.color.r; g = i; b = paint.color.b}
#
# ;; gslide_vc.add_change_listener (mk_listener_gslide)
#
# let (bslide_w, bslide_vc) = slider 0 (blue)
#
# let mk_listener_bslide (i: int) : unit =
#   paint.color &lt;- {r = paint.color.r; g = paint.color.g; b = i}
#
# ;; bslide_vc.add_change_listener (mk_listener_bslide)
# Thank you!
# Question:
# believe
# > 12.756306	I believe so
# > 11.468583	bump
# > 11.278235	What is the fix for this?
# > 9.773059	*RESOLVED
# > 9.709927	It's still there :(
# Question:
# foldright different fold placement last two arguments
# > 16.829433	How is fold_right any different from fold other than the placement of the last two arguments?
# > 15.56485	Would it be an acceptable solution to write a slightly modified ellipse function that takes in the arguments in a more clear way? For example, draw_box_ellipse that takes in two positions, corresponding to the bottom left and upper right corners?
# > 15.358456	In task 6, I have sliders implemented as shown here but there is some weird behavior with the lines around them at the right side. Additionally, similar to @1812 my sliders only work when I click or drag within one slider height above each's top edge. How should I go about fixing this?
#
# > 15.311161	Does thickness have to be an int? I used a bool to differentiate two thickness.
# > 15.288715	What is meant by setting the color in the graphics context for points (task 3), this probably has a really simple answer. I'm using black as a placeholder.
# Question:
# s difference calling invalidargument failwith
# > 14.734723	What's the difference between calling Invalid_argument and failwith?
# > 13.424484	for my function draw_points it has an "unbound value" error. I'm not sure where exactly was my syntax wrong.
# Thanks!
# > 13.338238	My make control has an error that says some record fields are undefined despite having written all of the functions. I'm wondering why this would be happening
# > 13.281499	I am a bit confused on what we are supposed to do for the second part of change_value... I think we have to iterate through the list of change_listeners, but what does it mean "the newly set value as the argument to each?" what is the argument in this case?
# > 13.264798	I'm confused as to how to implement the add_change_listener function in make_control given just a value v. Can someone help pls
# Question:
# ellipse rectangle appearing wrong place  supposed  something m wrong  edit  nevermind fixed
# > 15.732746	The ellipse and rectangle are appearing in the wrong place, below where they are supposed to be. Is there something I'm doing wrong?
#
# Edit: Nevermind I fixed it
# > 14.691555	I think the problem actually occurs when I try to draw the ellipse by dragging in any way other than top left to bottom right. Is this an issue related to passing in negative values somehow, and how do I think about fixing this?
# > 14.624521	i'm having a similar problem except with the rectangle which is gray... my graphics context is set and i've refreshed twice. any other thoughts?
# > 14.607083	I am done with p4 but have an error in repaint for drawing ellipses.
# When I draw an ellipse, the radius is always a little bigger than expected--the border of the ellipse goes beyond where my mouse position is.
# I think everything else works correctly--just not sure why this is happening.
# > 14.586061	The ellipse is only drawn when I start from the top left otherwise program crashes. I understand that there is an error in the math, more specifically negative values. Any idea what this error might be?
# Question:
# problem  rectangle showing different place  fix
# > 16.826302	I had the same problem. My rectangle is showing up in a different place. How did you fix this?
#
# > 15.388165	if you're changing the thickness of the line that's going to be drawn shouldn't it be mutable similar to color? I also tried making it immutable but the error still appeared
# > 15.354077	I am trying to make a thickness slider for Task 6. The part I am confused is how to make a scale. I am not sure what values does the p for mouseDrag output. Is it the from the same range as of the rectangle I made ?
#
# > 15.327348	Since we gave param a new parameter thickness, we would have to change repaint, but it doesn't say so in the directions above repaint. Does this mean I'm on the wrong track?
# > 15.282357	Umm I don't think that resolves my problem. I am confused why in other posts the instructors said that don't change thickness globally. However, the color button changes the global color.
# Question:
# widgettests vpair working  sure whether repaint function correct
# > 16.881987	All of the widgetTests for vpair are working, but I am not sure whether the repaint function is correct.
# > 15.973046	I am returning an hpair for two widgets that I create in my checkbox function. Shouldn't hpair account for these factors already i.e. lining them up next to each other and repainting accordingly?
# > 15.827588	For list_layout why is it saying that the expression has 'a -&gt; 'b instead of widget even though we know that pair takes in widgets?
# > 15.8231	My checkbox is working (tested via lightbulb) and I have invoked the line width by using add_change_listener and have updated everything in my repaint and paint_action to account for thickness. However, the thickness is not changing when I click my checkbox. Is this something wrong with my value_controller?
# > 15.759726	I had the same issue where every instance of me using module or graphics or deque has an unbound module error. No other files of mine have any errors. I also tried cleaning rebuilding and clearing google chrome's cache after logging out to no avail. HELP!
# Question:
# updating paintrepaint drawpoints method  set color graphics context graphics context immutable
# > 15.521735	When updating Paint.repaint for the draw_points method, how do we set the color in the graphics context if the graphics context is immutable?
# > 14.632323	Whoops, I didn't see the instructions for doing this in action and repaint. Do all the tasks in "Updating Paint.paint_action" and "Updating Paint.repaint" complete what is explained in "Extending the Shape Type," not including making the constructor?
# > 14.563044	In Task 3, are we supposed to be updating:
#
# let paint : state = {mutable mode: ...mutable color: ...mutable preview: ......}
#
# and
#
# type state = {shape =...mode =...color = ...preview = ......}
#
# for PointMode? The directions in Codio imply that we are, but there's no explicit reference to this in the instructions
# > 14.561942	I saw a previous question about "unbound module draw_points". I have an "unbound value draw_points" error in my paint.ml function as I am trying to add the Points (c, ps) to repaint. How can I fix this?
# > 14.530617	At what position should the checkbox be in this canvas? When I'm calling draw_rect and draw_string in repaint, I'm not sure what points to input because if it is a generic widget, then the location should be generic too, or am I understanding this wrong?
# Question:
# try calling drawpoints method repaint  says unbound module  added drawpoints gctx signature  could issue
# > 16.602203	When I try calling my draw_points method in repaint, it says I have an unbound module. I have added draw_points to the gctx signature. What could be the issue?
# > 15.978958	I saw a previous question about "unbound module draw_points". I have an "unbound value draw_points" error in my paint.ml function as I am trying to add the Points (c, ps) to repaint. How can I fix this?
# > 15.894469	I'm confused about what the following is trying to say. Don't we just create two variables x y and set them to the ocaml coords then plug in the other variables? What precaution should we have regarding using the native Ocaml function?
#
# Note that calling any native drawing method (such as Graphics.draw_rect) also requires conversion of the coordinates from our widget-local top-left-origin system to the bottom-left-origin system that the  Graphics library assumes.
# > 15.871142	For my slider I made it take in a gctx and an int so that I could give each one a distinct color like in the example, but for some reason it still draw the rectangle black and idk why. What's wrong with writing the code like this? How does draw_rect inside the repaint function decide what graphics context to use if not the one I'm providing it?
#
# Widget.slider (with_color Gctx.top_level Gctx.red)
# > 15.870461	In paint.ml it says my slider function (which I wrote in widget) is an unbound value. Is there somewhere else in my code I should've implemented slider in order to use it in paint?
# Question:
# similar issue able find syntax error apart one comes try call drawpoints repaint
# > 16.700146	I am having a similar issue but I have not been able to find a syntax error apart from the one that comes when I try to call draw_points in repaint
# > 15.8649025	I have passes the widget test for checkboxes, and I try to implement thickness now.
# I guess I should be using "add_change_listener" in the paint.ml, but I don't understand how to use it. And I am especially confused with what bool value it should take in?
# > 15.82759	It was suggested that we use something like
# let points =
#    begin match paint.preview with
#    | Some (Points (_, ps)) -&gt; ps
#    | _ -&gt; []
#    end in
# to get the parameters needed before adding a shape with those parameters to the deque. Is there anything wrong with just getting the whole shape from the preview to insert into the deque?
# > 15.802269	For my slider I made it take in a gctx and an int so that I could give each one a distinct color like in the example, but for some reason it still draw the rectangle black and idk why. What's wrong with writing the code like this? How does draw_rect inside the repaint function decide what graphics context to use if not the one I'm providing it?
#
# Widget.slider (with_color Gctx.top_level Gctx.red)
# > 15.798036	my checkbox also passes all test cases, but when i run lightbulb my lights change when i drag my mouse over them but not when I click. i'm confused how it could pass the clicking tests if it doesn't work the way it's supposed to be implemented. also any pointers on how to fix handle would be appreciated!
# Question:
# converting written code hpairs hlists  account hpairs  broken   instructions say  listlayout hpair  w1  w2  w3  …  wn  hpair w1  hpair w2  …  hpair wn1 wn  …    hpair  hpair x y   hpair  hpair  b  c   would represented list form calling hlist
# > 16.862974	When converting the written code from hpairs to hlists, how do we account for how the hpairs are "broken up?"
#
# The instructions say that :
#
# list_layout hpair [w1;w2;w3;…;wn] is the same the as hpair w1 (hpair w2 (… (hpair wn-1 wn) …))
#
# but what if we have: hpair (hpair x y) (hpair (hpair (a b) c)...how would this be represented in list form when calling hlist?
# > 15.284877	let repaint (g: gctx) : unit =
#   let draw_shape (s: shape) : unit =
#     begin match s with
#       | Line (c,p1, p2) -&gt; draw_line (with_params g c) p1 p2
#     end in
#   Deque.iterate draw_shape paint.shapes;
# Hello!
#
# I'm on task 3 right now, and I got an error in Ocaml saying that the pattern matching is not exhuastive for the code above. I think I accidentally deleted the patter after Line {c,p}, p2. What should the code be instead? Thank you so much!
# > 15.260291	Hello,
#
# I'm having trouble figuring out why my paint window gets drawn the way it does at the end of task 1.
#
# It's my understanding that vlist should stack elements in the list on top of each other. So if i were to call vlist on [w1; w2; w3] it would draw (from bottom to top) w1 w2 w3. However, i got the opposite, i.e. (from bottom to top) w3 w2 w1.
#
# I can fix this visually by reversing the order of the list I input to paint_widget, but I'm not sure whether that's actually a fix or whether there's a bigger problem in vlist, list_layout, etc. Any indication as to where I might have gone wrong?
#
# Thank you!
# > 15.259242	 I am getting a compiler error on this line when I run it. (ocaml doesn't have red errors on the side for me.  I am pattern matching the two positions to get the x and y postions. What could be wrong with this?
#
# begin match p1 with  | c (x1,y1) -&gt;  begin match p2 with  | d (x2,y2) -&gt; draw_ellipse (with_params g c) (abs ((x1 + x2)/2),  abs ((y1 + y2.x)/2)) (abs (x1-x2)) (abs (y1-y2)) end  end
# > 15.258914	I implemented the button for Points under Task 3 and it appears on the paint application.  However, whenever I press it on the paint application, the mode doesn't switch.  Is there something I'm doing wrong or should I come to office hours?
#
# let w_points, lc_points, nc_points = button "Point"
#
# ;; nc_lines.add_event_listener (mouseclick_listener ( fun () -&gt; (paint.mode &lt;- PointMode; paint.preview &lt;- None )))
# Question:
# s difference  hpair  hpair x y   hpair  hpair  b  c  hpair x  hpair  hpair y b  c
# > 15.464767	So there's no difference between: hpair (hpair x y) (hpair (hpair (a b) c)
#
# and
#
# hpair x (hpair (hpair y b) c)) ?
#
#
# > 13.07176	When converting the written code from hpairs to hlists, how do we account for how the hpairs are "broken up?"
#
# The instructions say that :
#
# list_layout hpair [w1;w2;w3;…;wn] is the same the as hpair w1 (hpair w2 (… (hpair wn-1 wn) …))
#
# but what if we have: hpair (hpair x y) (hpair (hpair (a b) c)...how would this be represented in list form when calling hlist?
# > 12.223562	let repaint (g: gctx) : unit =
#   let draw_shape (s: shape) : unit =
#     begin match s with
#       | Line (c, p1, p2) -&gt; draw_line (with_params g c) p1 p2
#       | Points (c, ps) -&gt; Gctx.draw_points (with_params g c) ps
#     end in
# For the given code (inside the pattern match starting from Line (c, p1, p2)), it is calling draw_line inside paint.ml, but draw_line is a function defined in Gctx.ml. I was wondering how this works and whether I could do the same for draw_points instead of doing Gctx.draw_points. Thank you!
# > 12.176002	I added to gctx these functions.
# let thicken (g: gctx) : gctx = { g with line_thickness = 8} let thin (g: gctx) : gctx = { g with line_thickness = 2}
#
# I also added in my gctx.mli file these
# (** Produce a new gctx with thick line width *)val thicken : gctx -&gt; gctx
# (** Produce a new gctx with thin line width *)val thin : gctx -&gt; gctx
#
# But when I called thicken in paint.ml I got unbound value error?
# > 12.1601305
# rm -rf g.ml
# cp g-js.ml.x g.ml
# ocamlbuild -use-ocamlfind -pkg js_of_ocaml -pkg js_of_ocaml-lwt -pkg js_of_ocaml-lwt.graphics lightbulb.byte
# Circular dependencies: "eventloop.cmo" already seen in
#   [ "paint.cmo"; "widget.cmo"; "eventloop.cmo" ]
#
# Hint: Recursive traversal of subdirectories was not enabled for this build,
#   as the working directory does not look like an ocamlbuild project (no
#   '_tags' or 'myocamlbuild.ml' file). If you have modules in subdirectories,
#   you should add the option "-r" or create an empty '_tags' file.
#
#   To enable recursive traversal for some subdirectories only, you can use the
#   following '_tags' file:
#
#       true: -traverse
#       &lt;dir1&gt; or &lt;dir2&gt;: traverse
#
# Compilation unsuccessful after building 26 targets (22 cached) in 00:00:00.
# make: *** [lightbulb.byte] Error 9
# codio@button-promise:~/workspace$
# I was just messing around in widget.ml and paint.ml when suddenly my code stopped compiling. Any idea what the cause could be? I don't see any red lines or anything like that, which is strange.
# Question:
# line preview works like normal except drag mouse canvas release mouse outside canvas preview line go away unless click canvas  normal behavior mean s bug code
# > 18.630972	My line preview works like normal except when I drag the mouse off the canvas and release the mouse outside of the canvas the preview line does not go away unless I click the canvas again. Is this normal behavior or does this mean there's a bug in my code?
# > 17.900143	When I am in "preview mode" (aka) dragging my mouse around, then I move my mouse outside the canvas and unpress my mouse, the line stays. Also when I move my mouse back over the canvas it still tracks my mouse though I am not dragging which clearly breaks the program. Can I get a hint at how I can fix this?
# > 17.802948	Hello,
#
# I'm a little confused by the instructions:
#
# "You also need to modify the function associated with the Undo button to reset the paint.preview shape toNone. In addition, if the paint.mode is LineEndMode, then reset it to LineStartMode—this prevents strange behavior when the user starts drawing a line, drags the mouse off the canvas, and then clicks the Undo button."
#
# Should this last part also be implemented in the undo function?
# > 17.796167	I have implemented the paint_action function so that the mouse drag feature draws the line rather than the two clicks, but when I use it in the paint application, it seems like each line I draw takes longer to appear on the screen. I'm wondering if this is normal, or if I did something incorrectly in my implementation of paint_action...
# > 17.749653	I don't completely understand these instructions:
#
# Finally, if a mouse release event (Gctx.MouseUp) was detected, the user has stopped dragging the mouse to draw points. In this case, do the following:
# Extract the list of points from paint.preview, if there is a value present, and then clear the preview.If the list of points is not empty, then insert a Points shape into the deque. (It wouldn't make sense to insert an empty shape into the deque, since it would a waste of space.)
#
#
# So far, in my pattern matching of MouseUp, I have
#
# | PointMode -&gt;             begin match paint.preview with             | Some (Points (_, ps)) -&gt; paint.preview &lt;- None;             | _ -&gt; ()             end
# I think this satisfies the first bullet point, but I don't understand what the second one is trying to ask us to do.
# Question:
# want us delete todo comments complete homework
# > 14.7736845	Do you want us to delete the Todo comments as we complete the homework?
# > 12.816651	Kind of confused about the syntax; I'm told that I have a syntax error, but I thought this code would be executable since I have iterated through everything in the history, and only if the preview is not none, I want to use the draw_shape to paint another line.
# > 12.808819	I keep getting a syntax error for repaint in checkbox, but I don't know what's wrong with it. Can someone please help :(
# > 12.77885	I've been changing the y part of the size for vpair but nothing changes when I open Paint, why is this?
# > 12.778085	For my make_control function, the only test that's failing is the change_value test where the value is changed from 1 to 2. Currently, the value apparently doesn't change, could anyone help see why? Thanks
# Question:
# test drawpoint drawpoints functions correct
# > 15.988709	How do I test if my draw_point and draw_points functions are correct?
# > 14.441567	I saw a previous question about "unbound module draw_points". I have an "unbound value draw_points" error in my paint.ml function as I am trying to add the Points (c, ps) to repaint. How can I fix this?
# > 14.390797	I implemented draw_point and draw_points but no points are showing up when I click in the canvas. draw_point is VERY similar to draw_rect, why isn't anything showing up?
# > 14.328827
# I don't understand why draw_points is unbound value when I defined the function already.
# > 14.307823	Yes, I understand that that function you're speaking of is draw_point which we implemented earlier but the types don't match.
#
# For example in draw_points, p is a list and,
#
#  List.iter f p
#
# Where here f is a function that draws one point. The only function that does this is draw_point so if we substitute draw_point for f
#
# (List.iter drawpoint g p)
#
# Produces a type error because draw_point takes in a point, not  a point list. But in doing something like
#
# let f = (fun ("I don't know what goes here)" -&gt; unit ()) in
#
# I'm not sure how to set f to draw_point while it's missing the point parameter. I've reviewed the lecture notes on partial applications but I'm still lost.
# Question:
# completing task 1 change current application looks
# > 15.970283	Should completing task 1 change how the current application looks?
# > 14.54579	Would a redo feature be considered a valid choice for task 6?
# > 14.534524	For adding Points to the deque in paint_action, (Task 3, "Extending the Shape Type") how would I add a list of points? In other words, how would I get access to all the points that I pass when I am dragging my mouse?
# > 14.515626	In task 6, I have sliders implemented as shown here but there is some weird behavior with the lines around them at the right side. Additionally, similar to @1812 my sliders only work when I click or drag within one slider height above each's top edge. How should I go about fixing this?
#
# > 14.499586	Can I get a bump on this? I sat in office hours for 2 straight hours and neither I or either of the TAs had a solution to this bug. Additionally both suggestions posted on this thread don't work. I didn't even come close to completing Task 5 because of this.
# Question:
# handle checkbox widget  check someone clicked checkbox    patternmatching gctxevent passed  event mouseup change value valuecontroller  events nt anything
# > 17.451725	For the handle in the checkbox widget, how should we check that someone clicked on the checkbox?
# Is it by::
#          pattern-matching the gctx.event that is passed in, if the event is MouseUp then change the value of the value_controller; for all other events don't do anything
# > 16.845312	My RGB sliders are functional (as in they are changing the rgb values of the pen) but are not repainting themselves - my code is structured the same way as my checkbox code so I'm not sure why.  Is there any error I am overlooking in my code?
#
#
# let slider_listener (cp: int value_controller) :  event_listener =
#   fun (g: Gctx.gctx) (e: Gctx.event) -&gt;
#       let x,_  = Gctx.event_pos e g in
#       begin match Gctx.event_type e with
#       |Gctx.MouseDrag -&gt; cp.change_value x
#       |Gctx.MouseDown -&gt; cp.change_value x
#       |Gctx.MouseUp -&gt; cp.change_value x
#       |_ -&gt; ()
#       end
#
# let slider (init: int) (w: int) (c: Gctx.color) (name: string) : widget * int value_controller =
#
#    let vc = make_control init in
#
#    let slider_builder (init: int) (width:int) (c: Gctx.color)
#       : widget * notifier_controller =
#
#         let repaint_slider (gc:Gctx.gctx) =
#           Gctx.fill_rect (Gctx.with_color gc c) (0, 9) (init, 9);
#           in
#        canvas (width,9) repaint_slider in
#
#   let slider, nc = slider_builder (vc.get_value()) w c in
#    nc.add_event_listener (slider_listener vc);
#
#    let l, _ = label name in
#   let full = hlist [slider; space (5,5); l] in
#
#
#   let bordered = border full in
#   bordered, vc
#
#
#
#
#
#
# > 16.828485	I am getting a "make: Nothing to be done for `all'" when building paint ever since implementing my slider function. I looked through everything and really can't find what's wrong with my slider function. Here is what I added to widget for slider (and I did update widget.mli):
#
# let slider_listener (cp: int value_controller) :  event_listener =
#   fun (g: Gctx.gctx) (e: Gctx.event) -&gt;
#       let x,_  = Gctx.event_pos e g in
#       begin match Gctx.event_type e with
#       |Gctx.MouseDrag -&gt; cp.change_value x
#       |_ -&gt; ()
#       end
#
# let slider (init: int) (w: int) (c: Gctx.color) : widget * int value_controller =
#    let vc = make_control init in
#       let slider_builder (init: int) (width:int) (c: Gctx.color)
#       : widget * notifier_controller =
#
#         let repaint_slider (gc:Gctx.gctx) =
#           Gctx.fill_rect (Gctx.with_color gc c) (0, 9) (init - 1, 9);
#           in
#        canvas (width,9) repaint_slider in
#
#   let slider, nc = slider_builder (vc.get_value()) w c in
#    nc.add_event_listener (slider_listener vc);
#
#   let bordered = border slider in
#   bordered, vc
# Here is what I added to paint:
# let w_rslider, vc_rslider = slider 0 255 red
#
# ;; vc_rslider.add_change_listener (fun v -&gt; paint.color &lt;- {r = v; g = paint.color.g; b = paint.color.b} )
#
# let w_gslider, vc_gslider = slider 0 255 green
#
# ;; vc_gslider.add_change_listener (fun v -&gt; paint.color &lt;- {r = paint.color.r; g = v; b = paint.color.b} )
#
# let w_bslider, vc_bslider = slider 0 255 blue
#
# ;; vc_bslider.add_change_listener (fun v -&gt; paint.color &lt;- {r = paint.color.r; g = paint.color.g; b = v} )...
# let rgb_toolbar : widget = vlist [w_rslider; spacer; w_gslider; spacer; w_bslider].....let paint_widget = vlist [paint_canvas; spacer; mode_toolbar; spacer; rgb_toolbar; spacer; color_toolbar]
#
# > 16.816595	so in the handle portion of my slider function, I do a pattern matching on the events (mouseup, mousedown, mousedrag) but I don't know what to actually match on for begin match.
# in paint_action, i know that event was passed in as one of the parameters. am i supposed to do a similar thing here?
# > 16.808292	i am getting the following error when i try to compile
#
# File "paint.ml", line 277, characters 22-28:
# Error: This function has type
#          int -&gt; Gctx.color -&gt; Widget.widget * int Widget.value_controller
#        It is applied to too many arguments; maybe you forgot a `;'.
# Command exited with code 2.
#
# can you point me to what I am doing wrong?
# Question:
# tried  nt seem changing value valuecontroller  tests clicking failing
# > 17.470493	I tried it, but it doesn't seem to be changing the value in the value_controller, because the tests for clicking are failing.
# > 16.418724	I tried using the position as local to my widget, but it still doesn't work. I think it's because of the value from the MouseDrag and am not sure.
# > 16.407272	For my make_control function, the only test that's failing is the change_value test where the value is changed from 1 to 2. Currently, the value apparently doesn't change, could anyone help see why? Thanks
# > 16.359138	Any tips on how I should debug this? I don't know why it thinks I'm trying to make an int value_controller...
#
# > 16.347334	i am getting the following error when i try to compile
#
# File "paint.ml", line 277, characters 22-28:
# Error: This function has type
#          int -&gt; Gctx.color -&gt; Widget.widget * int Widget.value_controller
#        It is applied to too many arguments; maybe you forgot a `;'.
# Command exited with code 2.
#
# can you point me to what I am doing wrong?
# Question:
# codio nt cooperating bc gives red dots saying  unbound  module literally nt understand things arent working  took  paintml  homework files decided try  start clean  codio put red dots clean file shook  anything  help would appreciated  thanks
# > 18.547686	Codio isn't cooperating with me b/c it gives me all these red dots saying "unbound" module and I literally don't understand why any of these things aren't working.
#
# I then took "paint.ml" from the Homework Files and decided to try and "start clean" again but Codio then put red dots on the CLEAN file and I was shook...
#
# so is there anything I can do now? Any help would be appreciated.
#
# Thanks :)
# > 17.922647	There is a "to do" comment in gctx.ml (right above the event handling section) that I haven't addressed, though everything is working fine.  I also don't understand what it is directing, so I'm not sure whether I'm missing something necessary or not.  Can someone let me know what this is referring to?  Thanks!
#
# (* TODO: You will need to add several "wrapped" versions of ocaml graphics *)(* functions here for Tasks 2, 4, and possibly 5 and 6 *)
# > 17.911907	When I clean and build my code I get unbound errors all over on things that were not underlined before or modified. For example,  Deque.iterate, shapes, and mode to name a few. This happened once before - I let codio go for a while and it fixed itself, however, after I tried cleaning and building again, the errors reappeared. This time, I've tried refreshing the page several times and restarting codio but the errors stay. Is there anything that I'm doing wrong? Thank you
# > 17.873522	I was working on my code, and all of the sudden I started getting this error "Unbound type constructor widget" for hpair and button as well. I undid all of the changes I made, but this is still showing up. I don't know why.
#
# After a few more moments, it's now started happening for all of the types defined in Gctx as well
# > 17.867758	My paint application isn't displayed properly and I keep seeing that it is the vpair function that is messing everything up but I can't figure out why mine doesn't work.  I've spent over a day on this one part.  Any help is much appreciated.  Here is my code:
#
# let vpair (w1: widget) (w2: widget) : widget = {  repaint = (fun (g:Gctx.gctx) -&gt; w1.repaint g;    let g = Gctx.translate g (snd (0, (w1.size()))) in     w2.repaint g);  handle = (fun (g:Gctx.gctx) (e:Gctx.event) -&gt;     if event_within g e (w1.size())    then w1.handle g e    else let g = (Gctx.translate g (snd (0, (w1.size())))) in      if event_within g e (w2.size ()) then w2.handle g e else ());  size = (fun () -&gt; let (x1,y1) = w1.size () in    let (x2,y2) = w2.size () in (max x1 x2, y1 + y2)) }
#
# Question:
# ve tried building cleaning project five times red dots still persist —  clean  file downloaded hw5 webpage also responds poorly even cleaning stuff  tips proceed
# > 18.741653	I've tried building and cleaning my project five times but the red dots still persist — the "clean" file that I downloaded from the HW5 webpage also responds poorly even after cleaning and stuff.
#
# Any more tips on how to proceed from here?
# > 17.904846	My thickness check box works perfectly, however for some reason the actual box that gets filled in keeps appearing above my label as shown in the screenshot. I have been trying to debug for sometime now but I can not figure out why it is still going above it as in my checkbox widget it is coming out as an hpair, but is not being drawn as an hpair for some reason. I tried looking on piazza for similar questions but my searches did not come up with any other posts so sorry if i missed one by accident. Thanks!
#
#
# > 17.882803	There is nothing at all :( My vpair passed all the widget tests as well. I tried cleaning the project and building t again; trying on a different browser and different laptop, but still nothing showed up.
# > 17.77803	I randomly started getting this compilation error in my gctx.ml file : The module Graphics is an alias for module G, which is missing. I am also getting "Unbound module Gctx" and "Unbound module Widget" in my other files. I have tried logging off and logging back on multiple times. I've tried cleaning my project, and I have even tried switching computers. I am not sure what the issue is because this was not happening before
# > 17.702505	It also shows that the value goes like this when dragging from left to right: 2,1,0,1,2,3...,255. My current thoughts are that this may have something to do with the border, but I'm not sure why because the gctx should update accordingly. Any help would be very appreciated!
# Question:
# similar issue hw5 file  logging  clearing cache logging back fixed
# > 15.672675	I had a similar issue for my hw5 file. Logging out, clearing my cache and logging back in fixed it for me.
# > 14.448375	I had the same issue where every instance of me using module or graphics or deque has an unbound module error. No other files of mine have any errors. I also tried cleaning rebuilding and clearing google chrome's cache after logging out to no avail. HELP!
# > 14.256098	I am returning an hpair for two widgets that I create in my checkbox function. Shouldn't hpair account for these factors already i.e. lining them up next to each other and repainting accordingly?
# > 14.220993	i deleted it but now its telling me my function cluster which clusters the radio_functions is unbound. i didn't have to put checkbox in the paint.mli. why would this occur?
# > 14.218261	I don't really understand which widgets were supposed to be making a list of? Are we supposed to be deleting the code for color_toolbar and implementing our own version of it?
# Question:
# issue every instance using module graphics deque unbound module error  files mine errors  also tried cleaning rebuilding clearing google chrome s cache logging avail  help
# > 18.70888	I had the same issue where every instance of me using module or graphics or deque has an unbound module error. No other files of mine have any errors. I also tried cleaning rebuilding and clearing google chrome's cache after logging out to no avail. HELP!
# > 17.878231	When I clean and build my code I get unbound errors all over on things that were not underlined before or modified. For example,  Deque.iterate, shapes, and mode to name a few. This happened once before - I let codio go for a while and it fixed itself, however, after I tried cleaning and building again, the errors reappeared. This time, I've tried refreshing the page several times and restarting codio but the errors stay. Is there anything that I'm doing wrong? Thank you
# > 17.851915	Whenever I run paint, the blank window pops up but nothing appears on it until I mouse over it. I have the same problem with drawing the lines that they do not appear until I mouse away from where I moused up. Is this just codio lagging or a weird bug? I do not know what could have caused it because we were given the code for the original canvas and mode and color toolbars.
# > 17.841553	When I refreshed my browser, the top few lines of widget.ml are underlined in red ("unbound record field native") and I'm not sure how to fix it in order to properly build my code. Codio error or did I accidentally delete something important?
# > 17.822727	I know this has been asked before, but I checked my code over and over and I keep getting the unbound ____ error for almost everything and in every file. I didn't change anything in my code (and previously, it allowed me to run the paint program and have a pop-up and now I can't) and I don't have an extra semicolon anywhere. I also tried clearing my data and logging back out and in.
#
# Nevermind, I deleted a random line of text and added the line back and it suddenly worked again only in my paint.ml file but my gctx.ml still has the error
# Question:
# try implement widgetvlist paintwidget  end getting two black rectangles screen run paint  leave original hpair code  implementations widgethlist seem working fine  nt know occurring  also  making list widgets first inputting widgethlist widgetvlist  another way implement efficient
# > 17.677591	When I try to implement Widget.vlist in paint_widget, I end up getting two black rectangles on the screen when I run paint. When I leave in the original hpair code, the other implementations of Widget.hlist seem to be working fine, so I don't know why this is occurring.
#
# Also, should I be making a list of widgets first and then inputting that into Widget.hlist or Widget.vlist, or is there another way to implement that which is more efficient?
# > 17.124619	So, a drop-down menu will just be a widget in widget.ml (using functions from gctx.ml). I can use it in paint to choose between different types of dotted lines. I don't think I will animate the drop-down, its repaint method will be based on a boolean value that tells whether the menu is open or not. Although I do see that this is very similar to a radio button apart from the fact that it saves space. I see the implementation as pretty challenging too as it might require two value controllers (one for which option in the menu is chosen and another for whether the menu is open or not) and I would also have to consider the situation when the drop-down is "above" some other features, so I'll attempt radio buttons and sliders first and then implement this if I have time.
# > 17.112324	Hi!
#
# I'm working on task 6, trying to do the color sliders. My first instinct to accomplish this task was to have the sliders affect the color (i.e paint.color.r &lt;- __), however I would have to make the type mutable in gctx, which wouldn't work b/c the gctx is supposed to be immutable.
#
# My next idea is to make the widget have a value controller that holds a number from 0-255 depending on the location of the mouse. Then I would create a mutable type in paint.ml that was of the same form as the type of color and could update. Then, ideally, I could apply that mutable color type to paint.color and all would be well and good. However, I have a few concerns I would like to run past someone before I change a bunch of my code:
#
# 1- Am I right in assuming I can't make the color type mutable? When I tried to change it it said that it was incompatible with the cmi but I don't know what that is.
#
# 2- Will it be an issue if I use a record within paint.ml and try to apply to to paint.color? I'm not sure it will work, since one is mutable and the other is not and because the type is only defined within Gctx so I don't think it will even be applicable.
#
# 3- Is it necessary to create an entirely new mutable state in paint that co-exists with color? It does not seem efficient, but I am not sure where else to look for color mutability.
#
# Basically all I've played around with so far has lead to errors but I can't make office hours. I think my main confusion rests in what is allowed to be mutable. I want to make sure that I am understanding this conceptually before I change a bunch of code.
#
# Thank you :)
# > 17.1063	all of my tests for Task 1 pass the widgetTest file and I've modified color toolbar and mode toolbar to use Widget.hlist and modified paint_widget to use Widget.vlist but when I run paint the exact same layout occurs. is the problem in widget.ml or paint.ml?
# > 17.105827	I am getting a "make: Nothing to be done for `all'" when building paint ever since implementing my slider function. I looked through everything and really can't find what's wrong with my slider function. Here is what I added to widget for slider (and I did update widget.mli):
#
# let slider_listener (cp: int value_controller) :  event_listener =
#   fun (g: Gctx.gctx) (e: Gctx.event) -&gt;
#       let x,_  = Gctx.event_pos e g in
#       begin match Gctx.event_type e with
#       |Gctx.MouseDrag -&gt; cp.change_value x
#       |_ -&gt; ()
#       end
#
# let slider (init: int) (w: int) (c: Gctx.color) : widget * int value_controller =
#    let vc = make_control init in
#       let slider_builder (init: int) (width:int) (c: Gctx.color)
#       : widget * notifier_controller =
#
#         let repaint_slider (gc:Gctx.gctx) =
#           Gctx.fill_rect (Gctx.with_color gc c) (0, 9) (init - 1, 9);
#           in
#        canvas (width,9) repaint_slider in
#
#   let slider, nc = slider_builder (vc.get_value()) w c in
#    nc.add_event_listener (slider_listener vc);
#
#   let bordered = border slider in
#   bordered, vc
# Here is what I added to paint:
# let w_rslider, vc_rslider = slider 0 255 red
#
# ;; vc_rslider.add_change_listener (fun v -&gt; paint.color &lt;- {r = v; g = paint.color.g; b = paint.color.b} )
#
# let w_gslider, vc_gslider = slider 0 255 green
#
# ;; vc_gslider.add_change_listener (fun v -&gt; paint.color &lt;- {r = paint.color.r; g = v; b = paint.color.b} )
#
# let w_bslider, vc_bslider = slider 0 255 blue
#
# ;; vc_bslider.add_change_listener (fun v -&gt; paint.color &lt;- {r = paint.color.r; g = paint.color.g; b = v} )...
# let rgb_toolbar : widget = vlist [w_rslider; spacer; w_gslider; spacer; w_bslider].....let paint_widget = vlist [paint_canvas; spacer; mode_toolbar; spacer; rgb_toolbar; spacer; color_toolbar]
# Question:
# make list widgets  inputs hlist second input widget part list widgets
# > 16.103817	but how do we make a list of widgets? and for the inputs of hlist- is the second input widget part of the list of widgets?
# > 15.109938	When coding checkbox in widget.ml, how do we access the mutable record fields in make_control which is the second argument of the tuple for the widget itself (first argument of tuple)?
# > 15.021861	I'm really confused where we get the list of widgets to pass into list_layouts in Task 1. Do we just create a list? If so, what widgets do we put into the list?
# > 14.911329	When I try to implement Widget.vlist in paint_widget, I end up getting two black rectangles on the screen when I run paint. When I leave in the original hpair code, the other implementations of Widget.hlist seem to be working fine, so I don't know why this is occurring.
#
# Also, should I be making a list of widgets first and then inputting that into Widget.hlist or Widget.vlist, or is there another way to implement that which is more efficient?
# > 14.895118	I added a change listener value to the value_controller type signature in both widget.ml and widget.mli to store all of the change_listeners in, but when I define my add_change_listener function I get the error "unbound value change_listener"?
# Question:
# think similar problem either vpair vlist  see many black lines edit layout  vpair vlist passed test cases  trace errors
# > 16.974415	i think i am having a similar problem with either vpair or vlist-- i see many black lines after i edit the layout, but both vpair and vlist passed all of the test cases. how can i trace my errors?
# ...
# > 18.49216	I think I should be storing the x position of the mouse cursor in the value controller. I currently have the following in my handle but I don't know if this is a valid way of doing this. Furthermore the line
# let xpos = fst pos in
# gives an error with pos underlined as "expression is Gctx.gctx -&gt; position but expression of type 'a * 'b expected"
#
# handle =
#  ( fun (g: Gctx.gctx) (e: Gctx.event) -&gt;  (*what do i use the Gctx.gctx for????*)
#     let click = Gctx.event_type e in
#     let pos = Gctx.event_pos e in
#     let xpos = fst pos in
#     begin match click with
#     (*how do I get the mouse coordinate to add to the int value controller? *)
#       | Gctx.MouseDown -&gt; (slider_state.change_value (xpos);)
#       | Gctx.MouseDrag -&gt; (slider_state.change_value (xpos);)
#
#       | _ -&gt; ()
#     end
#     );
# Should I be storing the mouse x coords here and does this account for the dynamic updating when you're trying to drag the slider?
# > 17.930689	In my slider, I match on my event type and I know that the event e also has a position tuple but when I try to define a tuple (x,y), to access the x coordinate, I get an error when using Gctx.ocaml_coords that says Unbound value. How can I fix this error or is there a different way I'm supposed to access mouse position?
# > 17.913794	1) Should I use a start mode and end mode in ellipse just like in line?
#
# 2) The first line of paint_action is as follows:
#     let p  = event_pos event gc in  (* mouse position *)
#     In the pattern matching if I write LineEndMode p1,
#    i'm confused about which one is my original and which is my new point p1 or  p?
# > 17.876421	For my slider I made it take in a gctx and an int so that I could give each one a distinct color like in the example, but for some reason it still draw the rectangle black and idk why. What's wrong with writing the code like this? How does draw_rect inside the repaint function decide what graphics context to use if not the one I'm providing it?
#
# Widget.slider (with_color Gctx.top_level Gctx.red)
# > 17.870148	Hi, in the following code I'm getting the error " Syntax error after unclosed (, expecting ')' " on the very last else statement. I've gone to office hours and still can't seem to find the source. Help?
#
# repaint =
#   (
#   fun (g: Gctx.gctx) -&gt;
#         let width = 2 in
#         let height = 2 in
#         Gctx.draw_rect g (0,0) (width,height); (*draw the square regardless of state*)
#         Gctx.draw_string g (width + 1, 0) s;   (*draw the string regardless of state*) (*does this have to be a label???*)
#         if checkbox_state.get_value()
#         then (*draw check on box*)
#         Gctx.draw_line g (0,0) (width,height);
#         Gctx.draw_line g (width,0) (0,height);
#         else () (*do not draw checkmark*)
#    );
# Question:
# return type gctxeventpos e position tuple type int  int  named variable pos thought could extract first value  nt undestand gctxeventpos e would returning function actual tuple
# > 15.740871	The return type of Gctx.event_pos e should be a position which is tuple of type int * int. Which is why I named the variable pos and why I thought I could extract the first value from it. I don't undestand why Gctx.event_pos e would be returning the function and not the actual tuple.
# > 14.948489	let make_control (v: 'a) : 'a value_controller =
#   let cntrl = {flist = []; vall = v} in
# I get an unbound value error for flist, and I don't understand why. The example in the slides uses a very similar set up doing:
#
# let mk_incr () : unit -&gt; int =
# (* this ctr is private to the returned function *)
# let ctr = { count = 0 } in
# Where could this error be coming from?
#
# Thanks
# > 14.889254	let adjustcolor (i: int) : unit =begin match paint.color with| {r; g; b} -&gt; paint.color &lt;- {i; g; b};
#
# For some reason I get an error that this record expression is supposed to have type Gctx.color but i does not belong to type Gctx.color.
#
# Isn't a color just a record with three ints?
# If I just use straight up ints e.g. {10; 10; 10} I get an error that after unclosed { expecting "with". What's going on here?
# > 14.851687	I just don't know why it keeps saying "unbound value size" and meanwhile saying " undefined record fields size"...
#
# let slider (init: int) : widget * int value_controller =
#   let sl_controller = make_control init in
#   let w' =
#   { repaint = (fun (g: Gctx.gctx) -&gt;
#         Gctx.draw_rect g (0,10) (256,0);
#         Gctx.fill_rect g (0,9) (sl_controller.get_value(),1));
#
#     handle = (fun (g: Gctx.gctx) (e: Gctx.event): unit -&gt; (
#     begin match Gctx.event_type e with
#     | MouseDrag -&gt;
#       let p = fst(Gctx.event_pos e g) in
#         sl_controller. change_value p
#     | MouseDown -&gt;
#       let p = fst(Gctx.event_pos e g) in
#         sl_controller. change_value p
#     | _ -&gt; ()
#     end );
#
#     size = (fun () -&gt; (256,10));}
#     in (w', sl_controller)
# > 14.835259	I think I should be storing the x position of the mouse cursor in the value controller. I currently have the following in my handle but I don't know if this is a valid way of doing this. Furthermore the line
# let xpos = fst pos in
# gives an error with pos underlined as "expression is Gctx.gctx -&gt; position but expression of type 'a * 'b expected"
#
# handle =
#  ( fun (g: Gctx.gctx) (e: Gctx.event) -&gt;  (*what do i use the Gctx.gctx for????*)
#     let click = Gctx.event_type e in
#     let pos = Gctx.event_pos e in
#     let xpos = fst pos in
#     begin match click with
#     (*how do I get the mouse coordinate to add to the int value controller? *)
#       | Gctx.MouseDown -&gt; (slider_state.change_value (xpos);)
#       | Gctx.MouseDrag -&gt; (slider_state.change_value (xpos);)
#
#       | _ -&gt; ()
#     end
#     );
# Should I be storing the mouse x coords here and does this account for the dynamic updating when you're trying to drag the slider?
# Question:
# since m already comfortable codio  thinking sticking  would worth switch eclipse
# > 17.473566	Since I'm already comfortable with codio, I was thinking of sticking with that. But would it be worth my while to switch to eclipse?
# > 15.977835	It also shows that the value goes like this when dragging from left to right: 2,1,0,1,2,3...,255. My current thoughts are that this may have something to do with the border, but I'm not sure why because the gctx should update accordingly. Any help would be very appreciated!
# > 15.967507	I've read all the piazza posts and they seem to deal with when all the previous lines change to thick or the lines don't change to thick at all, but in my case the lines that were thin still remain thin moving forward it's just that when I try and create new lines they are all thick regardless of whether the box is checked or not.
#
# I'm not sure if I have to change something in the handle function or something with how the thickness is changed and any direction would be great
# > 15.929931	I thought I could pattern match on paint.preview since I wanted to get the point list and insert them to the dequeue
# > 15.894903	I finished 6 and was wondering what is the appropriate amount of comments I should make throughout widget, paint and gctx? What is expected and what is overkill? Thanks!
# Question:
# use weighted average function given us alphablend function
# > 15.339009	Can we use the weighted average function given to us in the alphablend function?
# > 13.445486	Does it also make sense to do a coordinate conversion for the tuple dimension in draw_rect () in addition to position?
# > 13.419969	In the instructions, it tells us to use the fold_right function. Would we be using this along with anon. function? or can we just call list.fold_right on the list_layout arguments?
# > 13.373843	values input into the draw_ellipse function?
#
# > 13.297457	Awesome! Thank you for the response, could you explain a bit more about "using a hidden state in the closure?" I guess it means you need to call the function get value in order to get the value instead of looking at it and inherently getting the value right away?
# Question:
# pixel  methods constructors require us reference instance variables  access  something like thispixel  reference redgreenblue values  int   create constructor available inside constructor method
# > 18.441788	In Pixel, all the methods after the constructors require us to reference the instance variables. How do we access these? Something like this.pixel. How can we reference the the red/green/blue values? The int[] we create in the constructor is only available inside the constructor method.
# > 17.765429	For my slider I made it take in a gctx and an int so that I could give each one a distinct color like in the example, but for some reason it still draw the rectangle black and idk why. What's wrong with writing the code like this? How does draw_rect inside the repaint function decide what graphics context to use if not the one I'm providing it?
#
# Widget.slider (with_color Gctx.top_level Gctx.red)
# > 17.727936	I'm confused about what the following is trying to say. Don't we just create two variables x y and set them to the ocaml coords then plug in the other variables? What precaution should we have regarding using the native Ocaml function?
#
# Note that calling any native drawing method (such as Graphics.draw_rect) also requires conversion of the coordinates from our widget-local top-left-origin system to the bottom-left-origin system that the  Graphics library assumes.
# > 17.67369	Even though shapes that I drew before clicking the checkbox thickens and not widgets outside the canvas, is the problem still with the gctx? I did create a with_thickness function that produces a new gctx with the thickness and incorporate that in set_graphics_state.
# > 17.655851	In Task 5 make_controller, I defined value and listener_list in terms of ref. But as I define the functions of 'a value_controller, there is an error with add_change_listener, saying "Unbound record field List.add_change_listener"
#
# I don't get where the error comes from since this is all in widget.ml
#
# Thank you very much!
# Question:
# briefer question  allowed add instance variables pixel class
# > 16.05975	To be briefer with my question, are we allowed to add instance variables to the pixel class?
# > 14.773107	I am having trouble figuring out how I should amend the function since paint.preview has type option. Can you give me a hint?
# > 14.7414875	So I have implemented a thickness slider by adding a new int state but for some reason, I cannot get it to work. Is there any way to fix it?
# > 14.733092	Do we need to define repaint, handle, and size in the checkbox function?
# > 14.728259	For the sliders, are we allowed to use int_of_float to convert floats into ints?
# Question:
# m running gui rotate image  rotatecw code  turns bluishnavy color  something wrong pixel class
# > 17.64835	I'm running the GUI and when I rotate the image (with the rotatecw code) it all turns to a bluish/navy color. Is there something wrong with my Pixel class?
# > 16.901375	For my slider I made it take in a gctx and an int so that I could give each one a distinct color like in the example, but for some reason it still draw the rectangle black and idk why. What's wrong with writing the code like this? How does draw_rect inside the repaint function decide what graphics context to use if not the one I'm providing it?
#
# Widget.slider (with_color Gctx.top_level Gctx.red)
# > 16.851437	I'm changing this to private because it is about my specific implementation. So, I figured out that the tests aren't passing because widgetTest.ml uses the click55 event, which is a MouseDown event that is located at (5,5). However, my implementation of checkbox is an hlist of a label, a space, and a custom widget that is essentially a rectangle with either an x drawn on it or not depending on the state of the value controller. I put the actual changing of the value controller in the handle function of the custom widget, so the toggling of the checkbox only happens when the user actually clicks on the actual box (not the label or the spacer). So, the tests don't pass because (5,5) is a point that falls within the label, so nothing triggers. Isn't this desired behavior?
# > 16.830824	i am getting the following error when i try to compile
#
# File "paint.ml", line 277, characters 22-28:
# Error: This function has type
#          int -&gt; Gctx.color -&gt; Widget.widget * int Widget.value_controller
#        It is applied to too many arguments; maybe you forgot a `;'.
# Command exited with code 2.
#
# can you point me to what I am doing wrong?
# > 16.822079	Hello!
#
# In implementing my color slider, I wanted it such that my red value for the color is 255 * a fraction representing where I am in the slider in relation to the entire slider bar.
#
# However, the fraction often comes out as a decimal value, but rgb values can't be decimals.
#
# How do you cast on Ocaml and are we allowed to?
#
# Thank You :D
# Question:
# helps  orientation completely correct  color
# > 16.859505	if this helps, the orientation is completely correct, just not the color
# > 15.125325	Umm I don't think that resolves my problem. I am confused why in other posts the instructors said that don't change thickness globally. However, the color button changes the global color.
# > 15.111578	Is there a way to automatically make the Paint application pop up in a larger window? Some of my functionality works best when all of the elements are all contained on the page. I know I can always manually expand the screen, but I'm wondering if there's a way to do that automatically
# > 15.067637	My lightbulb works, and I have tried to implement the changing line thickness similar to the implementation of color, but I can't seem to get the lines to be drawn thick... If someone could point me in the right direction, I would really appreciate it.
# > 15.010966	Hi!
# I just finished task 5, but when i click on thick, all of the thickness change (including the previously drawn lines and borders). I am not sure what's a good way to fix that. :((
# Question:
# submit page still showed hw5 point 0  getting grade gui back midterm
# > 17.483055	My submit page still showed HW5 point as 0. Are we getting our grade on GUI back before midterm?
# > 16.324335	I was working on my code, and all of the sudden I started getting this error "Unbound type constructor widget" for hpair and button as well. I undid all of the changes I made, but this is still showing up. I don't know why.
#
# After a few more moments, it's now started happening for all of the types defined in Gctx as well
# > 16.238367	I see what you're saying but that wasn't actually my issue. I accidentally called my new ellipse function the same as the old one so it was getting confused.
#
# The issue now is that Gctx.draw_ellipse_from_box is throwing an unbound error despite the fact that I very definitely defined and implemented it in Gctx.
# > 16.228424	This bug prevented me from even moving on to testing the check box functionality. I sat in office hours staring at this for 2 hours and so far no suggestions have helped. I didn't complete Task 5 because of this.
#
#  " Syntax error after unclosed (, expecting ')' " on the very last else statement
#
# repaint =
#   (
#   fun (g: Gctx.gctx) -&gt;
#         let width = 2 in
#         let height = 2 in
#         Gctx.draw_rect g (0,0) (width,height); (*draw the square regardless of state*)
#         Gctx.draw_string g (width + 1, 0) s;   (*draw the string regardless of state*)
#         if checkbox_state.get_value()
#         then (*draw check on box*)
#         Gctx.draw_line g (0,0) (width,height);
#         Gctx.draw_line g (width,0) (0,height);
#         else () (*do not draw checkmark*)
#    );
#
#
#
# > 16.221	When I submit my zip file I get the below message. I know that the scripts don't grade on the spot but is this message normal?
#
# Compiler Output
# make: *** No rule to make target 'gctx.cmo', needed by 'ocamlbin'.  Stop.
#
#
# Test Output
# No executable produced.
